# %%
# Packages / libraries
import os #provides functions for interacting with the operating system
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# remove warnings
import warnings
warnings.simplefilter(action='ignore', category=RuntimeWarning)

# %% [markdown]
# # **1. Loading Dataset**

# %%
# Loading the data
new_data = pd.read_csv("/kaggle/input/seperated-data/India_Delhi.csv")

# print the shape
print(new_data.shape)

#runs the first 5 rows
new_data.head()
# Out:
# (2399, 12)
#          Date    co   no2   o3   pm10   pm25  so2  humidity  pressure  \
# 0  2014-12-29  14.1  36.2  3.2  218.0  307.0  4.2       NaN       NaN
# 1  2014-12-30  20.4  36.8  4.8  330.0  367.0  5.8       NaN       NaN
# 2  2014-12-31  12.7  28.7  7.8  137.0  202.0  6.3       NaN       NaN
# 3  2015-01-01  20.8  66.5  5.2  230.0  382.0  9.9       NaN       NaN
# 4  2015-01-02  12.7  33.9  6.0   81.0  172.0  4.2       NaN       NaN
#
#    temperature  wind-speed Country_City
# 0          NaN         NaN  India_Delhi
# 1          NaN         NaN  India_Delhi
# 2          NaN         NaN  India_Delhi
# 3          NaN         NaN  India_Delhi
# 4          NaN         NaN  India_Delhi

# %%
# Find the minimum and maximum dates
min_date = new_data['Date'].min()
max_date = new_data['Date'].max()

print('Minimum date:', min_date)
print('Maximum date:', max_date)
# Out:
# Minimum date: 2014-12-29
# Maximum date: 2023-10-01

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2399 entries, 0 to 2398
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          2399 non-null   object
#  1   co            2399 non-null   float64
#  2   no2           2399 non-null   float64
#  3   o3            2399 non-null   float64
#  4   pm10          2398 non-null   float64
#  5   pm25          2398 non-null   float64
#  6   so2           2399 non-null   float64
#  7   humidity      1698 non-null   float64
#  8   pressure      1698 non-null   float64
#  9   temperature   1698 non-null   float64
#  10  wind-speed    1629 non-null   float64
#  11  Country_City  2399 non-null   object
# dtypes: float64(10), object(2)
# memory usage: 225.0+ KB

# %%
new_data.describe()
# Out:
#                 co          no2           o3         pm10         pm25  \
# count  2399.000000  2399.000000  2399.000000  2398.000000  2398.000000
# mean      9.325594    16.870946     9.480700   131.572143   164.397832
# std       3.715709     7.805715     4.829603    77.174642    64.829240
# min       0.100000     5.000000     2.400000    12.000000    30.000000
# 25%       7.050000    10.600000     6.000000    82.000000   123.000000
# 50%       8.400000    15.800000     8.200000   120.000000   160.000000
# 75%      10.700000    21.500000    11.800000   160.000000   189.000000
# max      30.600000    66.500000    40.300000   999.000000   577.000000
#
#                so2     humidity     pressure  temperature   wind-speed
# count  2399.000000  1698.000000  1698.000000  1698.000000  1629.000000
# mean      5.702751    60.708304   985.184923    26.338869     1.101964
# std       2.289821    17.138084    10.022854     6.631277     0.493156
# min       1.700000    13.000000   743.000000     6.200000     0.300000
# 25%       4.000000    48.500000   979.800000    22.100000     0.800000
# 50%       5.300000    63.000000   983.900000    28.600000     1.000000
# 75%       7.100000    74.000000   990.400000    31.100000     1.300000
# max      19.800000    99.100000  1020.500000    38.000000     4.600000

# %%
# Investigate all the elements whithin each Feature

for column in new_data:
    # Handle numerical and string columns differently
    if new_data[column].dtype == 'object':  # Check if column is of object type
        unique_vals = new_data[column].unique()  # pandas unique for strings
    else:
        unique_vals = np.unique(new_data[column])  # numpy unique for numerical types

    nr_values = len(unique_vals)
    if nr_values < 14:
        print('The number of values for feature {} :{} -- {}'.format(column, nr_values,unique_vals))
    else:
        print('The number of values for feature {} :{}'.format(column, nr_values))
# Out:
# The number of values for feature Date :2397
# The number of values for feature co :200
# The number of values for feature no2 :328
# The number of values for feature o3 :226
# The number of values for feature pm10 :320
# The number of values for feature pm25 :309
# The number of values for feature so2 :116
# The number of values for feature humidity :602
# The number of values for feature pressure :300
# The number of values for feature temperature :264
# The number of values for feature wind-speed :33
# The number of values for feature Country_City :1 -- ['India_Delhi']

# %%
new_data.isna().sum()
# Out:
# Date              0
# co                0
# no2               0
# o3                0
# pm10              1
# pm25              1
# so2               0
# humidity        701
# pressure        701
# temperature     701
# wind-speed      770
# Country_City      0
# dtype: int64

# %% [markdown]
# # **1.2 - Function**

# %%
print(os.listdir('/kaggle/usr/lib/function'))
# Out:
# ['__script__.py', '__results__.html', '__script__.ipynb', 'function.py', '__output__.json', 'custom.css']

# %%
import sys
sys.path.append("/kaggle/usr/lib/function")  # Add directory to the path

import function as fn

# %%
# Use the functions
new_data1 = fn.prepare_datetime_index(new_data, date_column='Date')
new_data1.head()
# Out:
#               co   no2   o3   pm10   pm25  so2  humidity  pressure  \
# Date
# 2014-12-29  14.1  36.2  3.2  218.0  307.0  4.2       NaN       NaN
# 2014-12-30  20.4  36.8  4.8  330.0  367.0  5.8       NaN       NaN
# 2014-12-31  12.7  28.7  7.8  137.0  202.0  6.3       NaN       NaN
# 2015-01-01  20.8  66.5  5.2  230.0  382.0  9.9       NaN       NaN
# 2015-01-02  12.7  33.9  6.0   81.0  172.0  4.2       NaN       NaN
#
#             temperature  wind-speed Country_City
# Date
# 2014-12-29          NaN         NaN  India_Delhi
# 2014-12-30          NaN         NaN  India_Delhi
# 2014-12-31          NaN         NaN  India_Delhi
# 2015-01-01          NaN         NaN  India_Delhi
# 2015-01-02          NaN         NaN  India_Delhi

# %%
# Use the functions
new_data2 = fn.fill_pollutant_values(new_data1)
print(new_data2.isna().sum())
# Out:
# co              0
# no2             0
# o3              0
# pm10            0
# pm25            0
# so2             0
# humidity        0
# pressure        0
# temperature     0
# wind-speed      0
# Country_City    0
# dtype: int64

# %% [markdown]
# **Check**

# %%
# Create a complete range of dates
full_range = pd.date_range(start=new_data2.index.min(), end=new_data2.index.max())

# Find missing dates
missing_dates = full_range.difference(new_data2.index)
print("Missing Dates:")
print(missing_dates)
# Out:
# Missing Dates:
# DatetimeIndex(['2015-07-06', '2015-07-07', '2015-07-08', '2015-07-09',
#                '2015-07-10', '2015-07-11', '2015-07-12', '2015-07-13',
#                '2015-07-14', '2015-07-15',
#                ...
#                '2022-03-18', '2022-03-19', '2022-03-20', '2022-03-21',
#                '2022-03-22', '2022-03-23', '2022-03-24', '2022-03-25',
#                '2022-03-26', '2022-03-27'],
#               dtype='datetime64[ns]', length=802, freq=None)

# %%
new_data3 = fn.impute_missing_dates(new_data2)

# %%
# Create a complete range of dates
full_range = pd.date_range(start=new_data3.index.min(), end=new_data3.index.max())

# Find missing dates
missing_dates = full_range.difference(new_data3.index)
print("Missing Dates:")
print(missing_dates)
# Out:
# Missing Dates:
# DatetimeIndex([], dtype='datetime64[ns]', freq='D')

# %%
duplicates = new_data3.index[new_data3.index.duplicated()]
print(f"Duplicate indexes: {duplicates}")
# Out:
# Duplicate indexes: DatetimeIndex([], dtype='datetime64[ns]', freq='D')

# %% [markdown]
# # **1.3.Normal AQI count, After Normal AQI count Smoothing AQI(IQR, Z-score, Rolling), (Preprocess Pollution --> Smooth Pollution --> Calculate smooth aqi).**

# %%
new_data4 = fn.calculate_aqi(new_data3, subindex_columns=['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'])

# %%
new_data4.head()
# Out:
#               co   no2   o3   pm10   pm25  so2   humidity    pressure  \
# 2014-12-29  14.1  36.2  3.2  218.0  307.0  4.2  60.691097  985.187382
# 2014-12-30  20.4  36.8  4.8  330.0  367.0  5.8  60.691097  985.187382
# 2014-12-31  12.7  28.7  7.8  137.0  202.0  6.3  60.691097  985.187382
# 2015-01-01  20.8  66.5  5.2  230.0  382.0  9.9  60.691097  985.187382
# 2015-01-02  12.7  33.9  6.0   81.0  172.0  4.2  60.691097  985.187382
#
#             temperature  wind-speed Country_City  Checks    AQI
# 2014-12-29      26.3352    1.102459  India_Delhi       6  307.0
# 2014-12-30      26.3352    1.102459  India_Delhi       6  367.0
# 2014-12-31      26.3352    1.102459  India_Delhi       6  202.0
# 2015-01-01      26.3352    1.102459  India_Delhi       6  382.0
# 2015-01-02      26.3352    1.102459  India_Delhi       6  172.0

# %%
new_data4.shape
# Out:
# (3199, 13)

# %% [markdown]
#  After Normal AQI count Smoothing AQI(IQR, Z-score, Rolling)

# %%
# Apply the outlier handling function to the 'AQI' column only
new_data4['AQI_smoothed_iqr'] = fn.handle_aqi_outliers(new_data4['AQI'], method='iqr')
new_data4['AQI_smoothed_zscore'] = fn.handle_aqi_outliers(new_data4['AQI'], method='zscore')
new_data4['AQI_smoothed_rolling'] = fn.handle_aqi_outliers(new_data4['AQI'], method='rolling')

# %%
new_data4.head()
# Out:
#               co   no2   o3   pm10   pm25  so2   humidity    pressure  \
# 2014-12-29  14.1  36.2  3.2  218.0  307.0  4.2  60.691097  985.187382
# 2014-12-30  20.4  36.8  4.8  330.0  367.0  5.8  60.691097  985.187382
# 2014-12-31  12.7  28.7  7.8  137.0  202.0  6.3  60.691097  985.187382
# 2015-01-01  20.8  66.5  5.2  230.0  382.0  9.9  60.691097  985.187382
# 2015-01-02  12.7  33.9  6.0   81.0  172.0  4.2  60.691097  985.187382
#
#             temperature  wind-speed Country_City  Checks    AQI  \
# 2014-12-29      26.3352    1.102459  India_Delhi       6  307.0
# 2014-12-30      26.3352    1.102459  India_Delhi       6  367.0
# 2014-12-31      26.3352    1.102459  India_Delhi       6  202.0
# 2015-01-01      26.3352    1.102459  India_Delhi       6  382.0
# 2015-01-02      26.3352    1.102459  India_Delhi       6  172.0
#
#             AQI_smoothed_iqr  AQI_smoothed_zscore  AQI_smoothed_rolling
# 2014-12-29             307.0                307.0                 307.0
# 2014-12-30             367.0                367.0                 367.0
# 2014-12-31             202.0                202.0                 202.0
# 2015-01-01             382.0                158.0                 382.0
# 2015-01-02             172.0                172.0                 172.0

# %% [markdown]
# (Preprocess Pollution --> Smooth Pollution --> Calculate smooth aqi)

# %%
new_smooth = fn.calculate_smooth_aqi(new_data3, columns=['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'])
new_smooth.head()
# Out:
#                co        no2        o3        pm10        pm25       so2  \
# 2014-12-29  15.70  35.883333  5.366667  182.333333  268.166667  6.000000
# 2014-12-30  15.70  35.883333  5.366667  182.333333  268.166667  6.000000
# 2014-12-31  15.70  35.883333  5.366667  182.333333  268.166667  6.000000
# 2015-01-01  15.70  35.883333  5.366667  182.333333  268.166667  6.000000
# 2015-01-02  15.45  33.100000  5.816667  166.000000  249.500000  5.733333
#
#              humidity    pressure  temperature  wind-speed Country_City  \
# 2014-12-29  60.691097  985.187382      26.3352    1.102459  India_Delhi
# 2014-12-30  60.691097  985.187382      26.3352    1.102459  India_Delhi
# 2014-12-31  60.691097  985.187382      26.3352    1.102459  India_Delhi
# 2015-01-01  60.691097  985.187382      26.3352    1.102459  India_Delhi
# 2015-01-02  60.691097  985.187382      26.3352    1.102459  India_Delhi
#
#             AQI_Smooth
# 2014-12-29  268.166667
# 2014-12-30  268.166667
# 2014-12-31  268.166667
# 2015-01-01  268.166667
# 2015-01-02  249.500000

# %% [markdown]
# **AQI (normal, smooth_iqr, smooth_zscore, smooth_rolling, smooth)**

# %%
#normal
aqi_normal = new_data4['AQI']
aqi_normal.plot()
# Out:
# <Axes: >

# %%
#smooth_iqr
aqi_smooth_iqr = new_data4['AQI_smoothed_iqr']
aqi_smooth_iqr.plot()
# Out:
# <Axes: >

# %%
#smooth_zscore
aqi_smooth_zscore = new_data4['AQI_smoothed_zscore']
aqi_smooth_zscore.plot()
# Out:
# <Axes: >

# %%
#smooth_rolling
aqi_smooth_rolling = new_data4['AQI_smoothed_rolling']
aqi_smooth_rolling.plot()
# Out:
# <Axes: >

# %%
#smooth
aqi_smooth = new_smooth['AQI_Smooth']
aqi_smooth.plot()
# Out:
# <Axes: >

# %% [markdown]
# # **2.1. Splitting & Preprocessing the Raw Data(AQI_smoothed_zscore)**

# %% [markdown]
# aqi_smooth_zscore

# %%
new_data4.head(8)
# Out:
#               co   no2   o3   pm10   pm25  so2   humidity    pressure  \
# 2014-12-29  14.1  36.2  3.2  218.0  307.0  4.2  60.691097  985.187382
# 2014-12-30  20.4  36.8  4.8  330.0  367.0  5.8  60.691097  985.187382
# 2014-12-31  12.7  28.7  7.8  137.0  202.0  6.3  60.691097  985.187382
# 2015-01-01  20.8  66.5  5.2  230.0  382.0  9.9  60.691097  985.187382
# 2015-01-02  12.7  33.9  6.0   81.0  172.0  4.2  60.691097  985.187382
# 2015-01-03  14.3  27.8  5.2   98.0  179.0  5.6  60.691097  985.187382
# 2015-01-04  12.6  19.5  5.9  120.0  195.0  2.6  60.691097  985.187382
# 2015-01-05  13.1  19.1  8.4  114.0  185.0  2.5  60.691097  985.187382
#
#             temperature  wind-speed Country_City  Checks    AQI  \
# 2014-12-29      26.3352    1.102459  India_Delhi       6  307.0
# 2014-12-30      26.3352    1.102459  India_Delhi       6  367.0
# 2014-12-31      26.3352    1.102459  India_Delhi       6  202.0
# 2015-01-01      26.3352    1.102459  India_Delhi       6  382.0
# 2015-01-02      26.3352    1.102459  India_Delhi       6  172.0
# 2015-01-03      26.3352    1.102459  India_Delhi       6  179.0
# 2015-01-04      26.3352    1.102459  India_Delhi       6  195.0
# 2015-01-05      26.3352    1.102459  India_Delhi       6  185.0
#
#             AQI_smoothed_iqr  AQI_smoothed_zscore  AQI_smoothed_rolling
# 2014-12-29             307.0                307.0                 307.0
# 2014-12-30             367.0                367.0                 367.0
# 2014-12-31             202.0                202.0                 202.0
# 2015-01-01             382.0                158.0                 382.0
# 2015-01-02             172.0                172.0                 172.0
# 2015-01-03             179.0                179.0                 179.0
# 2015-01-04             195.0                195.0                 195.0
# 2015-01-05             185.0                185.0                 185.0

# %%
new_data4.columns
# Out:
# Index(['co', 'no2', 'o3', 'pm10', 'pm25', 'so2', 'humidity', 'pressure',
#        'temperature', 'wind-speed', 'Country_City', 'Checks', 'AQI',
#        'AQI_smoothed_iqr', 'AQI_smoothed_zscore', 'AQI_smoothed_rolling'],
#       dtype='object')

# %% [markdown]
# ***Working with aqi_smooth_zscore***

# %%
aqi_smooth_zscore
# Out:
# 2014-12-29    307.0
# 2014-12-30    367.0
# 2014-12-31    202.0
# 2015-01-01    158.0
# 2015-01-02    172.0
#               ...
# 2023-09-27    134.0
# 2023-09-28    144.0
# 2023-09-29    155.0
# 2023-09-30    155.0
# 2023-10-01    152.0
# Freq: D, Name: AQI_smoothed_zscore, Length: 3199, dtype: float64

# %%
# Function to define window_size and convert data into X (features) and y (labels)
def new_data_to_X_y(new_data, window_size, train_pct, val_pct, test_pct):
    # Convert data to numpy array
    new_data_as_np = new_data.to_numpy()
    
    # Split data based on percentages
    total_len = len(new_data_as_np)
    train_end = int(train_pct * total_len)
    val_end = train_end + int(val_pct * total_len)
    
    # Prepare train, val, and test splits
    train_data = new_data_as_np[:train_end]
    val_data = new_data_as_np[train_end:val_end]
    test_data = new_data_as_np[val_end:]
    
    # Helper function to create X and y
    def create_X_y(data):
        X, y = [], []
        for i in range(len(data) - window_size):
            row = [[a] for a in data[i:i + window_size]]
            X.append(row)
            label = data[i + window_size]
            y.append(label)
        return np.array(X), np.array(y)
    
    # Create X and y for train, validation, and test
    X_train, y_train = create_X_y(train_data)
    X_val, y_val = create_X_y(val_data)
    X_test, y_test = create_X_y(test_data)
    
    return (X_train, y_train), (X_val, y_val), (X_test, y_test)

# %%
#passing data to function

# WINDOW_SIZE = 6
# train_pct=0.7
# val_pct=0.2
# test_pct=0.1
(X_train1, y_train1), (X_val1, y_val1), (X_test1, y_test1) = new_data_to_X_y(aqi_smooth_zscore, 6, 0.7, 0.2, 0.1)

# shapes
print("Train shapes:", X_train1.shape, y_train1.shape)
print("Validation shapes:", X_val1.shape, y_val1.shape)
print("Test shapes:", X_test1.shape, y_test1.shape)
# Out:
# Train shapes: (2233, 6, 1) (2233,)
# Validation shapes: (633, 6, 1) (633,)
# Test shapes: (315, 6, 1) (315,)

# %% [markdown]
# # **2.2. Model Training & Testing**

# %%
# libraries for building model and testing
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.losses import MeanSquaredError, MeanAbsoluteError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
from keras.regularizers import l2
from keras.callbacks import EarlyStopping

# %% [markdown]
# # LSTM-32-8(zscore)

# %%
model1 = Sequential()
model1.add(InputLayer((6, 1))) # 6 timestamp , 1 feature
model1.add(LSTM(32)) # LSTM layer with 16 units
model1.add(Dense(8, activation='relu')) # activation function- ReLU with 8 dense layer

model1.add(Dense(1, 'linear')) # output - linear and data- 1

model1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 32)                  │           4,352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 8)                   │             264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,625 (18.07 KB)
#  Trainable params: 4,625 (18.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp1 = ModelCheckpoint('/kaggle/working/model1.keras', save_best_only=True)

model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0005), 
               metrics=[RootMeanSquaredError()])

# %%
model1.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=100, 
           callbacks=[cp1])
# Out:
# Epoch 1/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 28537.8125 - root_mean_squared_error: 168.9061 - val_loss: 32861.7734 - val_root_mean_squared_error: 181.2782
# Epoch 2/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27471.1621 - root_mean_squared_error: 165.7379 - val_loss: 32683.8145 - val_root_mean_squared_error: 180.7867
# Epoch 3/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27139.5684 - root_mean_squared_error: 164.7052 - val_loss: 32415.2422 - val_root_mean_squared_error: 180.0423
# Epoch 4/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27085.3750 - root_mean_squared_error: 164.5641 - val_loss: 32058.6562 - val_root_mean_squared_error: 179.0493
# Epoch 5/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 26107.7051 - root_mean_squared_error: 161.5593 - val_loss: 31645.7910 - val_root_mean_squared_error: 177.8926
# Epoch 6/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26063.9199 - root_mean_squared_error: 161.4351 - val_loss: 30849.8477 - val_root_mean_squared_error: 175.6413
# Epoch 7/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25846.8906 - root_mean_squared_error: 160.7631 - val_loss: 30000.1621 - val_root_mean_squared_error: 173.2056
# Epoch 8/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24467.0898 - root_mean_squared_error: 156.4034 - val_loss: 29190.1621 - val_root_mean_squared_error: 170.8513
# Epoch 9/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23675.3535 - root_mean_squared_error: 153.8551 - val_loss: 28350.6895 - val_root_mean_squared_error: 168.3766
# Epoch 10/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22924.2168 - root_mean_squared_error: 151.3947 - val_loss: 27258.8594 - val_root_mean_squared_error: 165.1026
# Epoch 11/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 22449.7383 - root_mean_squared_error: 149.8137 - val_loss: 25831.2832 - val_root_mean_squared_error: 160.7211
# Epoch 12/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20953.5098 - root_mean_squared_error: 144.7350 - val_loss: 24458.3008 - val_root_mean_squared_error: 156.3915
# Epoch 13/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20086.3770 - root_mean_squared_error: 141.7025 - val_loss: 23185.4336 - val_root_mean_squared_error: 152.2676
# Epoch 14/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18311.0625 - root_mean_squared_error: 135.2962 - val_loss: 21847.1699 - val_root_mean_squared_error: 147.8079
# Epoch 15/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17382.2715 - root_mean_squared_error: 131.8290 - val_loss: 20628.5254 - val_root_mean_squared_error: 143.6263
# Epoch 16/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15986.0742 - root_mean_squared_error: 126.4297 - val_loss: 19404.5098 - val_root_mean_squared_error: 139.3001
# Epoch 17/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14633.7578 - root_mean_squared_error: 120.9617 - val_loss: 18166.8535 - val_root_mean_squared_error: 134.7845
# Epoch 18/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13394.2930 - root_mean_squared_error: 115.7255 - val_loss: 17032.4062 - val_root_mean_squared_error: 130.5083
# Epoch 19/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12798.3828 - root_mean_squared_error: 113.1166 - val_loss: 15953.1348 - val_root_mean_squared_error: 126.3057
# Epoch 20/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11574.1133 - root_mean_squared_error: 107.5737 - val_loss: 14933.8418 - val_root_mean_squared_error: 122.2041
# Epoch 21/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10510.2090 - root_mean_squared_error: 102.5053 - val_loss: 13966.7744 - val_root_mean_squared_error: 118.1811
# Epoch 22/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9363.9258 - root_mean_squared_error: 96.7190 - val_loss: 13062.3809 - val_root_mean_squared_error: 114.2908
# Epoch 23/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10162.3838 - root_mean_squared_error: 100.6314 - val_loss: 12210.1299 - val_root_mean_squared_error: 110.4995
# Epoch 24/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8495.4570 - root_mean_squared_error: 92.1408 - val_loss: 11437.8428 - val_root_mean_squared_error: 106.9479
# Epoch 25/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7483.6128 - root_mean_squared_error: 86.4451 - val_loss: 10715.1631 - val_root_mean_squared_error: 103.5141
# Epoch 26/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6906.5391 - root_mean_squared_error: 83.0967 - val_loss: 10048.5557 - val_root_mean_squared_error: 100.2425
# Epoch 27/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6471.2563 - root_mean_squared_error: 80.3809 - val_loss: 9408.6387 - val_root_mean_squared_error: 96.9981
# Epoch 28/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5844.8979 - root_mean_squared_error: 76.4322 - val_loss: 8802.6016 - val_root_mean_squared_error: 93.8222
# Epoch 29/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5423.6763 - root_mean_squared_error: 73.6373 - val_loss: 8239.2520 - val_root_mean_squared_error: 90.7703
# Epoch 30/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4951.9536 - root_mean_squared_error: 70.3544 - val_loss: 7722.2339 - val_root_mean_squared_error: 87.8762
# Epoch 31/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4609.0552 - root_mean_squared_error: 67.8488 - val_loss: 7251.2900 - val_root_mean_squared_error: 85.1545
# Epoch 32/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4186.2646 - root_mean_squared_error: 64.6819 - val_loss: 6806.8379 - val_root_mean_squared_error: 82.5036
# Epoch 33/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3989.3616 - root_mean_squared_error: 63.1474 - val_loss: 6391.6904 - val_root_mean_squared_error: 79.9481
# Epoch 34/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3558.0105 - root_mean_squared_error: 59.5422 - val_loss: 6017.4873 - val_root_mean_squared_error: 77.5725
# Epoch 35/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3090.6772 - root_mean_squared_error: 55.5836 - val_loss: 5617.9785 - val_root_mean_squared_error: 74.9532
# Epoch 36/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2876.8130 - root_mean_squared_error: 53.6229 - val_loss: 5296.6016 - val_root_mean_squared_error: 72.7778
# Epoch 37/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2746.3486 - root_mean_squared_error: 52.3759 - val_loss: 5006.1479 - val_root_mean_squared_error: 70.7541
# Epoch 38/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2395.1179 - root_mean_squared_error: 48.9155 - val_loss: 4752.1694 - val_root_mean_squared_error: 68.9360
# Epoch 39/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 
# Epoch 68/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1088.4258 - root_mean_squared_error: 32.9658 - val_loss: 1883.0492 - val_root_mean_squared_error: 43.3941
# Epoch 69/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 924.3338 - root_mean_squared_error: 30.2706 - val_loss: 1847.8951 - val_root_mean_squared_error: 42.9872
# Epoch 70/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 980.8992 - root_mean_squared_error: 31.2949 - val_loss: 1807.4836 - val_root_mean_squared_error: 42.5145
# Epoch 71/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1011.6129 - root_mean_squared_error: 31.7558 - val_loss: 1778.6202 - val_root_mean_squared_error: 42.1737
# Epoch 72/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 991.3388 - root_mean_squared_error: 31.4480 - val_loss: 1756.2245 - val_root_mean_squared_error: 41.9073
# Epoch 73/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 997.6425 - root_mean_squared_error: 31.5682 - val_loss: 1726.8209 - val_root_mean_squared_error: 41.5550
# Epoch 74/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1128.2212 - root_mean_squared_error: 33.5635 - val_loss: 1698.6769 - val_root_mean_squared_error: 41.2150
# Epoch 75/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 963.5237 - root_mean_squared_error: 30.9679 - val_loss: 1683.9830 - val_root_mean_squared_error: 41.0364
# Epoch 76/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 924.7984 - root_mean_squared_error: 30.3752 - val_loss: 1652.8119 - val_root_mean_squared_error: 40.6548
# Epoch 77/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 888.9487 - root_mean_squared_error: 29.7459 - val_loss: 1646.3109 - val_root_mean_squared_error: 40.5748
# Epoch 78/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1037.3290 - root_mean_squared_error: 32.1811 - val_loss: 1606.9590 - val_root_mean_squared_error: 40.0869
# Epoch 79/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 866.4515 - root_mean_squared_error: 29.3544 - val_loss: 1603.6514 - val_root_mean_squared_error: 40.0456
# Epoch 80/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1051.2290 - root_mean_squared_error: 32.3998 - val_loss: 1558.7322 - val_root_mean_squared_error: 39.4808
# Epoch 81/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1051.2726 - root_mean_squared_error: 32.3882 - val_loss: 1550.0447 - val_root_mean_squared_error: 39.3706
# Epoch 82/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 859.1613 - root_mean_squared_error: 29.2572 - val_loss: 1523.7445 - val_root_mean_squared_error: 39.0352
# Epoch 83/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 886.9015 - root_mean_squared_error: 29.6564 - val_loss: 1513.7214 - val_root_mean_squared_error: 38.9066
# Epoch 84/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 905.3895 - root_mean_squared_error: 29.9993 - val_loss: 1496.1328 - val_root_mean_squared_error: 38.6799
# Epoch 85/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1006.7943 - root_mean_squared_error: 31.7104 - val_loss: 1471.0455 - val_root_mean_squared_error: 38.3542
# Epoch 86/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 927.5619 - root_mean_squared_error: 30.4292 - val_loss: 1473.7523 - val_root_mean_squared_error: 38.3895
# Epoch 87/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 947.7747 - root_mean_squared_error: 30.6955 - val_loss: 1439.3624 - val_root_mean_squared_error: 37.9389
# Epoch 88/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1107.3489 - root_mean_squared_error: 33.1146 - val_loss: 1445.3901 - val_root_mean_squared_error: 38.0183
# Epoch 89/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 965.9495 - root_mean_squared_error: 31.0221 - val_loss: 1416.1644 - val_root_mean_squared_error: 37.6320
# Epoch 90/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1016.5896 - root_mean_squared_error: 31.8440 - val_loss: 1406.2014 - val_root_mean_squared_error: 37.4994
# Epoch 91/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1003.7458 - root_mean_squared_error: 31.6246 - val_loss: 1397.1251 - val_root_mean_squared_error: 37.3781
# Epoch 92/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 948.4205 - root_mean_squared_error: 30.6455 - val_loss: 1383.9032 - val_root_mean_squared_error: 37.2008
# Epoch 93/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 940.7963 - root_mean_squared_error: 30.6482 - val_loss: 1381.0394 - val_root_mean_squared_error: 37.1623
# Epoch 94/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 955.4559 - root_mean_squared_error: 30.8700 - val_loss: 1371.6392 - val_root_mean_squared_error: 37.0356
# Epoch 95/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1066.4954 - root_mean_squared_error: 32.6285 - val_loss: 1347.4849 - val_root_mean_squared_error: 36.7081
# Epoch 96/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 946.1794 - root_mean_squared_error: 30.7044 - val_loss: 1335.4863 - val_root_mean_squared_error: 36.5443
# Epoch 97/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 921.9269 - root_mean_squared_error: 30.2987 - val_loss: 1320.7545 - val_root_mean_squared_error: 36.3422
# Epoch 98/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1040.8783 - root_mean_squared_error: 32.2182 - val_loss: 1335.7820 - val_root_mean_squared_error: 36.5484
# Epoch 99/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 921.5862 - root_mean_squared_error: 30.3177 - val_loss: 1342.1176 - val_root_mean_squared_error: 36.6349
# Epoch 100/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1007.2139 - root_mean_squared_error: 31.6571 - val_loss: 1303.2789 - val_root_mean_squared_error: 36.1010

# %%
from tensorflow.keras.models import load_model
model1 = load_model('/kaggle/working/model1.keras')

# %%
# Evaluate the model on the train data
train_result = model1.predict(X_train1)

# Calculate metrics
mse = mean_squared_error(y_train1, train_result)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_train1, train_result)
r2 = r2_score(y_train1, train_result)

# Print the results
print("Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (Accuracy): {r2:.4f}")
# Out:
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Evaluation Metrics:
# Mean Absolute Error (MAE): 17.7679
# Mean Squared Error (MSE): 963.4715
# Root Mean Squared Error (RMSE): 31.0398
# R-squared (Accuracy): 0.6949

# %%
# Evaluate the model on the validation data
val_result = model1.predict(X_val1)

# Calculate metrics
mse = mean_squared_error(y_val1, val_result)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_val1, val_result)
r2 = r2_score(y_val1, val_result)

# Print the results
print("Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (Accuracy): {r2:.4f}")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Evaluation Metrics:
# Mean Absolute Error (MAE): 26.2830
# Mean Squared Error (MSE): 1303.2790
# Root Mean Squared Error (RMSE): 36.1010
# R-squared (Accuracy): 0.7731

# %%
# Evaluate the model on the test data
test_result = model1.predict(X_test1)

# Calculate metrics
mse = mean_squared_error(y_test1, test_result)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test1, test_result)
r2 = r2_score(y_test1, test_result)

# Print the results
print("Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (Accuracy): {r2:.4f}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Evaluation Metrics:
# Mean Absolute Error (MAE): 19.6262
# Mean Squared Error (MSE): 688.0205
# Root Mean Squared Error (RMSE): 26.2301
# R-squared (Accuracy): 0.7574

# %%
train_predictions = model1.predict(X_train1).flatten()
train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_train1})
train_results
# Out:
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#       Train Predictions  Actuals
# 0            180.542526    195.0
# 1            191.842941    185.0
# 2            186.075272    208.0
# 3            204.486465    290.0
# 4            242.480347    267.0
# ...                 ...      ...
# 2228         213.367935    197.0
# 2229         199.764648    216.0
# 2230         215.444138    223.0
# 2231         219.720291    269.0
# 2232         240.227905    233.0
#
# [2233 rows x 2 columns]

# %%
plt.plot(train_results['Actuals'][1:50], label='Actual')
plt.plot(train_results['Train Predictions'][1:50], label='Predicted')
plt.legend()
plt.show()

# %%
val_predictions = model1.predict(X_val1).flatten()
val_results = pd.DataFrame(data={'Train Predictions':val_predictions, 'Actuals':y_val1})
val_results
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#      Train Predictions  Actuals
# 0           209.824387    183.0
# 1           193.352448    206.0
# 2           207.198273    189.0
# 3           194.972870    181.0
# 4           189.484818    189.0
# ..                 ...      ...
# 628         193.961075    193.0
# 629         206.551666    199.0
# 630         201.433380    197.0
# 631         199.189545    197.0
# 632         199.191071    190.0
#
# [633 rows x 2 columns]

# %%
plt.plot(val_results['Actuals'][1:50], label='Actual')
plt.plot(val_results['Train Predictions'][1:50], label='Predicted')
plt.legend()
plt.show()

# %%
test_predictions = model1.predict(X_test1).flatten()
test_results = pd.DataFrame(data={'Train Predictions':test_predictions, 'Actuals':y_test1})
test_results
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#      Train Predictions  Actuals
# 0           201.440430    190.0
# 1           194.599457    177.0
# 2           186.042831    172.0
# 3           179.669662    170.0
# 4           175.066284    197.0
# ..                 ...      ...
# 310         153.569351    134.0
# 311         139.265015    144.0
# 312         146.363052    155.0
# 313         152.458939    155.0
# 314         152.992172    152.0
#
# [315 rows x 2 columns]

# %%
plt.plot(test_results['Train Predictions'][1:50], label='Predicted')
plt.plot(test_results['Actuals'][1:50], label='Actual')
plt.legend()
plt.show()

# %% [markdown]
# # **GRU(zscore)**

# %%
model2 = Sequential()
model2.add(InputLayer((6, 1)))
model2.add(GRU(32))
model2.add(Dense(8, 'relu'))
model2.add(Dense(1, 'linear'))
model2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru (GRU)                            │ (None, 32)                  │           3,360 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 8)                   │             264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,633 (14.19 KB)
#  Trainable params: 3,633 (14.19 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp2 = ModelCheckpoint('/kaggle/working/model2.keras', save_best_only=True)
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0005), 
               metrics=[RootMeanSquaredError()])

# %%
model2.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), 
           epochs=100, callbacks=[cp2])
# Out:
# Epoch 1/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 27863.9355 - root_mean_squared_error: 166.9146 - val_loss: 32509.1621 - val_root_mean_squared_error: 180.3030
# Epoch 2/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27303.2832 - root_mean_squared_error: 165.2323 - val_loss: 32073.8984 - val_root_mean_squared_error: 179.0919
# Epoch 3/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26681.4551 - root_mean_squared_error: 163.3124 - val_loss: 31520.8184 - val_root_mean_squared_error: 177.5410
# Epoch 4/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26467.6211 - root_mean_squared_error: 162.6749 - val_loss: 30649.3203 - val_root_mean_squared_error: 175.0695
# Epoch 5/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26432.6152 - root_mean_squared_error: 162.5145 - val_loss: 29518.1738 - val_root_mean_squared_error: 171.8085
# Epoch 6/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24264.2168 - root_mean_squared_error: 155.7608 - val_loss: 28258.3945 - val_root_mean_squared_error: 168.1023
# Epoch 7/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 
# Epoch 63/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 965.3494 - root_mean_squared_error: 31.0563 - val_loss: 1564.7554 - val_root_mean_squared_error: 39.5570
# Epoch 64/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1039.1886 - root_mean_squared_error: 32.1996 - val_loss: 1548.1332 - val_root_mean_squared_error: 39.3463
# Epoch 65/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1103.1125 - root_mean_squared_error: 33.0339 - val_loss: 1519.9620 - val_root_mean_squared_error: 38.9867
# Epoch 66/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1184.4493 - root_mean_squared_error: 34.1782 - val_loss: 1504.5457 - val_root_mean_squared_error: 38.7885
# Epoch 67/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 995.5488 - root_mean_squared_error: 31.4487 - val_loss: 1482.2157 - val_root_mean_squared_error: 38.4996
# Epoch 68/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 934.4078 - root_mean_squared_error: 30.5083 - val_loss: 1465.5421 - val_root_mean_squared_error: 38.2824
# Epoch 69/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1036.8456 - root_mean_squared_error: 32.1431 - val_loss: 1453.6384 - val_root_mean_squared_error: 38.1266
# Epoch 70/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 973.8314 - root_mean_squared_error: 31.1649 - val_loss: 1423.1620 - val_root_mean_squared_error: 37.7248
# Epoch 71/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 919.8643 - root_mean_squared_error: 30.3118 - val_loss: 1425.6556 - val_root_mean_squared_error: 37.7579
# Epoch 72/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 995.4383 - root_mean_squared_error: 31.4647 - val_loss: 1417.5317 - val_root_mean_squared_error: 37.6501
# Epoch 73/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 963.2414 - root_mean_squared_error: 30.9594 - val_loss: 1377.0669 - val_root_mean_squared_error: 37.1089
# Epoch 74/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 945.9127 - root_mean_squared_error: 30.6953 - val_loss: 1359.1324 - val_root_mean_squared_error: 36.8664
# Epoch 75/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 922.8140 - root_mean_squared_error: 30.3065 - val_loss: 1375.6710 - val_root_mean_squared_error: 37.0900
# Epoch 76/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1004.2782 - root_mean_squared_error: 31.6532 - val_loss: 1411.7419 - val_root_mean_squared_error: 37.5732
# Epoch 77/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1051.1537 - root_mean_squared_error: 32.3934 - val_loss: 1380.6381 - val_root_mean_squared_error: 37.1569
# Epoch 78/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1019.8297 - root_mean_squared_error: 31.8130 - val_loss: 1317.8887 - val_root_mean_squared_error: 36.3027
# Epoch 79/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 922.0941 - root_mean_squared_error: 30.3316 - val_loss: 1308.2114 - val_root_mean_squared_error: 36.1692
# Epoch 80/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 913.6143 - root_mean_squared_error: 30.2160 - val_loss: 1325.5947 - val_root_mean_squared_error: 36.4087
# Epoch 81/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1007.4871 - root_mean_squared_error: 31.7309 - val_loss: 1368.0778 - val_root_mean_squared_error: 36.9875
# Epoch 82/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1024.9137 - root_mean_squared_error: 31.9686 - val_loss: 1305.5547 - val_root_mean_squared_error: 36.1325
# Epoch 83/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 837.7123 - root_mean_squared_error: 28.8961 - val_loss: 1251.3447 - val_root_mean_squared_error: 35.3744
# Epoch 84/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 912.6688 - root_mean_squared_error: 30.1336 - val_loss: 1293.0137 - val_root_mean_squared_error: 35.9585
# Epoch 85/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 961.9171 - root_mean_squared_error: 31.0030 - val_loss: 1241.5262 - val_root_mean_squared_error: 35.2353
# Epoch 86/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 934.7992 - root_mean_squared_error: 30.5676 - val_loss: 1256.2650 - val_root_mean_squared_error: 35.4438
# Epoch 87/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 973.8396 - root_mean_squared_error: 31.1912 - val_loss: 1278.2052 - val_root_mean_squared_error: 35.7520
# Epoch 88/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 964.3420 - root_mean_squared_error: 31.0335 - val_loss: 1226.6960 - val_root_mean_squared_error: 35.0242
# Epoch 89/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 916.3683 - root_mean_squared_error: 30.1941 - val_loss: 1262.0042 - val_root_mean_squared_error: 35.5247
# Epoch 90/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 871.2497 - root_mean_squared_error: 29.4854 - val_loss: 1231.3303 - val_root_mean_squared_error: 35.0903
# Epoch 91/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 965.3264 - root_mean_squared_error: 31.0244 - val_loss: 1232.6018 - val_root_mean_squared_error: 35.1084
# Epoch 92/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 986.0721 - root_mean_squared_error: 31.3741 - val_loss: 1248.7726 - val_root_mean_squared_error: 35.3380
# Epoch 93/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 982.9587 - root_mean_squared_error: 31.1661 - val_loss: 1230.9678 - val_root_mean_squared_error: 35.0852
# Epoch 94/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 888.3698 - root_mean_squared_error: 29.7887 - val_loss: 1231.9299 - val_root_mean_squared_error: 35.0989
# Epoch 95/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 964.7416 - root_mean_squared_error: 31.0287 - val_loss: 1215.4716 - val_root_mean_squared_error: 34.8636
# Epoch 96/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 958.6541 - root_mean_squared_error: 30.9439 - val_loss: 1192.1011 - val_root_mean_squared_error: 34.5268
# Epoch 97/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 904.2867 - root_mean_squared_error: 29.9843 - val_loss: 1256.7933 - val_root_mean_squared_error: 35.4513
# Epoch 98/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 902.1159 - root_mean_squared_error: 29.9775 - val_loss: 1224.1089 - val_root_mean_squared_error: 34.9873
# Epoch 99/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1044.8241 - root_mean_squared_error: 32.2229 - val_loss: 1246.1282 - val_root_mean_squared_error: 35.3005
# Epoch 100/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 931.4453 - root_mean_squared_error: 30.4372 - val_loss: 1231.5267 - val_root_mean_squared_error: 35.0931

# %%
from tensorflow.keras.models import load_model
model2 = load_model('/kaggle/working/model2.keras')

# %%
# Evaluate the model on the train data
train_result = model2.predict(X_train1)

# Calculate metrics
mse = mean_squared_error(y_train1, train_result)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_train1, train_result)
r2 = r2_score(y_train1, train_result)

# Print the results
print("Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (Accuracy): {r2:.4f}")
# Out:
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Evaluation Metrics:
# Mean Absolute Error (MAE): 18.2415
# Mean Squared Error (MSE): 946.3575
# Root Mean Squared Error (RMSE): 30.7629
# R-squared (Accuracy): 0.7004

# %%
# Evaluate the model on the validation data
val_result = model2.predict(X_val1)

# Calculate metrics
mse = mean_squared_error(y_val1, val_result)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_val1, val_result)
r2 = r2_score(y_val1, val_result)

# Print the results
print("Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (Accuracy): {r2:.4f}")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Evaluation Metrics:
# Mean Absolute Error (MAE): 25.6792
# Mean Squared Error (MSE): 1192.1011
# Root Mean Squared Error (RMSE): 34.5268
# R-squared (Accuracy): 0.7924

# %%
# Evaluate the model on the test data
test_result = model2.predict(X_test1)

# Calculate metrics
mse = mean_squared_error(y_test1, test_result)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test1, test_result)
r2 = r2_score(y_test1, test_result)

# Print the results
print("Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (Accuracy): {r2:.4f}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Evaluation Metrics:
# Mean Absolute Error (MAE): 19.7291
# Mean Squared Error (MSE): 688.5347
# Root Mean Squared Error (RMSE): 26.2399
# R-squared (Accuracy): 0.7572

# %%
train_predictions = model2.predict(X_train1).flatten()
train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_train1})
train_results
# Out:
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#       Train Predictions  Actuals
# 0            181.326370    195.0
# 1            189.011566    185.0
# 2            177.725510    208.0
# 3            207.609726    290.0
# 4            246.554764    267.0
# ...                 ...      ...
# 2228         215.171646    197.0
# 2229         195.951004    216.0
# 2230         227.049469    223.0
# 2231         221.781860    269.0
# 2232         247.359985    233.0
#
# [2233 rows x 2 columns]

# %%
plt.plot(train_results['Actuals'][1:50], label='Actual')
plt.plot(train_results['Train Predictions'][1:50], label='Predicted')
plt.legend()
plt.show()

# %%
val_predictions = model2.predict(X_val1).flatten()
val_results = pd.DataFrame(data={'Train Predictions':val_predictions, 'Actuals':y_val1})
val_results
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#      Train Predictions  Actuals
# 0           215.423828    183.0
# 1           192.431030    206.0
# 2           215.766708    189.0
# 3           190.179657    181.0
# 4           191.638382    189.0
# ..                 ...      ...
# 628         194.974380    193.0
# 629         229.266464    199.0
# 630         201.854507    197.0
# 631         216.281799    197.0
# 632         199.003677    190.0
#
# [633 rows x 2 columns]

# %%
plt.plot(val_results['Actuals'][1:50], label='Actual')
plt.plot(val_results['Train Predictions'][1:50], label='Predicted')
plt.legend()
plt.show()

# %%
test_predictions = model2.predict(X_test1).flatten()
test_results = pd.DataFrame(data={'Train Predictions':test_predictions, 'Actuals':y_test1})
test_results
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#      Train Predictions  Actuals
# 0           202.303070    190.0
# 1           190.582275    177.0
# 2           182.419754    172.0
# 3           172.578110    170.0
# 4           167.544373    197.0
# ..                 ...      ...
# 310         152.659698    134.0
# 311         140.358856    144.0
# 312         146.996994    155.0
# 313         153.037415    155.0
# 314         153.279892    152.0
#
# [315 rows x 2 columns]

# %%
plt.plot(test_results['Train Predictions'][1:50], label='Predicted')
plt.plot(test_results['Actuals'][1:50], label='Actual')
plt.legend()
plt.show()

# %% [markdown]
# # RNN(zscore)

# %%
model3 = Sequential()
model3.add(InputLayer((6, 1)))
model3.add(SimpleRNN(32))
model3.add(Dense(8, 'relu'))
model3.add(Dense(1, 'linear'))
model3.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)               │ (None, 32)                  │           1,088 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 8)                   │             264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,361 (5.32 KB)
#  Trainable params: 1,361 (5.32 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp3 = ModelCheckpoint('/kaggle/working/model3.keras', save_best_only=True)
model3.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0005), 
               metrics=[RootMeanSquaredError()])

# %%
model3.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), 
           epochs=100, callbacks=[cp3])
# Out:
# Epoch 1/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 28536.3789 - root_mean_squared_error: 168.9216 - val_loss: 32747.2793 - val_root_mean_squared_error: 180.9621
# Epoch 2/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 
# Epoch 30/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4148.9692 - root_mean_squared_error: 64.3705 - val_loss: 6851.8232 - val_root_mean_squared_error: 82.7757
# Epoch 31/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3689.7390 - root_mean_squared_error: 60.7197 - val_loss: 6407.0923 - val_root_mean_squared_error: 80.0443
# Epoch 32/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3643.2788 - root_mean_squared_error: 60.3259 - val_loss: 6027.8706 - val_root_mean_squared_error: 77.6394
# Epoch 33/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3250.4172 - root_mean_squared_error: 56.9704 - val_loss: 5651.2305 - val_root_mean_squared_error: 75.1747
# Epoch 34/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2888.1538 - root_mean_squared_error: 53.7081 - val_loss: 5344.6230 - val_root_mean_squared_error: 73.1069
# Epoch 35/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2616.3340 - root_mean_squared_error: 51.1234 - val_loss: 5077.8721 - val_root_mean_squared_error: 71.2592
# Epoch 36/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2428.9646 - root_mean_squared_error: 49.2269 - val_loss: 4778.4155 - val_root_mean_squared_error: 69.1261
# Epoch 37/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2319.1255 - root_mean_squared_error: 48.0858 - val_loss: 4541.5620 - val_root_mean_squared_error: 67.3911
# Epoch 38/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2115.5688 - root_mean_squared_error: 45.9629 - val_loss: 4321.9922 - val_root_mean_squared_error: 65.7419
# Epoch 39/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1911.3282 - root_mean_squared_error: 43.6583 - val_loss: 4128.9771 - val_root_mean_squared_error: 64.2571
# Epoch 40/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1873.7378 - root_mean_squared_error: 43.2624 - val_loss: 3944.1399 - val_root_mean_squared_error: 62.8024
# Epoch 41/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1933.5195 - root_mean_squared_error: 43.9421 - val_loss: 3786.9470 - val_root_mean_squared_error: 61.5382
# Epoch 42/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1711.6512 - root_mean_squared_error: 41.3567 - val_loss: 3632.2083 - val_root_mean_squared_error: 60.2678
# Epoch 43/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1601.7454 - root_mean_squared_error: 39.9656 - val_loss: 3510.5347 - val_root_mean_squared_error: 59.2498
# Epoch 44/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1575.4640 - root_mean_squared_error: 39.6450 - val_loss: 3359.0229 - val_root_mean_squared_error: 57.9571
# Epoch 45/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1653.0232 - root_mean_squared_error: 40.5888 - val_loss: 3240.0068 - val_root_mean_squared_error: 56.9211
# Epoch 46/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1489.8802 - root_mean_squared_error: 38.5815 - val_loss: 3132.2385 - val_root_mean_squared_error: 55.9664
# Epoch 47/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1429.3591 - root_mean_squared_error: 37.7708 - val_loss: 3039.7783 - val_root_mean_squared_error: 55.1342
# Epoch 48/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1256.4226 - root_mean_squared_error: 35.3207 - val_loss: 2934.7439 - val_root_mean_squared_error: 54.1733
# Epoch 49/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1482.5818 - root_mean_squared_error: 38.4260 - val_loss: 2866.8625 - val_root_mean_squared_error: 53.5431
# Epoch 50/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1495.5771 - root_mean_squared_error: 38.6220 - val_loss: 2771.3013 - val_root_mean_squared_error: 52.6432
# Epoch 51/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1400.6178 - root_mean_squared_error: 37.3808 - val_loss: 2704.6321 - val_root_mean_squared_error: 52.0061
# Epoch 52/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1340.9362 - root_mean_squared_error: 36.5036 - val_loss: 2626.0583 - val_root_mean_squared_error: 51.2451
# Epoch 53/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1072.9440 - root_mean_squared_error: 32.6856 - val_loss: 2568.7930 - val_root_mean_squared_error: 50.6833
# Epoch 54/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1238.1947 - root_mean_squared_error: 35.1094 - val_loss: 2499.6523 - val_root_mean_squared_error: 49.9965
# Epoch 55/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1260.6415 - root_mean_squared_error: 35.3792 - val_loss: 2416.1213 - val_root_mean_squared_error: 49.1541
# Epoch 56/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1258.0352 - root_mean_squared_error: 35.4004 - val_loss: 2388.9919 - val_root_mean_squared_error: 48.8773
# Epoch 57/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1254.3007 - root_mean_squared_error: 35.3224 - val_loss: 2301.1492 - val_root_mean_squared_error: 47.9703
# Epoch 58/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1191.0249 - root_mean_squared_error: 34.4659 - val_loss: 2267.4441 - val_root_mean_squared_error: 47.6177
# Epoch 59/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1097.2148 - root_mean_squared_error: 33.0938 - val_loss: 2180.9167 - val_root_mean_squared_error: 46.7003
# Epoch 60/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1226.2913 - root_mean_squared_error: 34.9440 - val_loss: 2131.7297 - val_root_mean_squared_error: 46.1707
# Epoch 61/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1213.9647 - root_mean_squared_error: 34.8145 - val_loss: 2087.1021 - val_root_mean_squared_error: 45.6848
# Epoch 62/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1148.4215 - root_mean_squared_error: 33.7883 - val_loss: 2045.8922 - val_root_mean_squared_error: 45.2315
# Epoch 63/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1055.2996 - root_mean_squared_error: 32.4568 - val_loss: 1984.3367 - val_root_mean_squared_error: 44.5459
# Epoch 64/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1201.7458 - root_mean_squared_error: 34.6212 - val_loss: 1960.0106 - val_root_mean_squared_error: 44.2720
# Epoch 65/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1129.2870 - root_mean_squared_error: 33.4979 - val_loss: 1902.0116 - val_root_mean_squared_error: 43.6121
# Epoch 66/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1257.0024 - root_mean_squared_error: 35.3758 - val_loss: 1865.4171 - val_root_mean_squared_error: 43.1905
# Epoch 67/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1062.5076 - root_mean_squared_error: 32.4977 - val_loss: 1835.8241 - val_root_mean_squared_error: 42.8465
# Epoch 68/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1051.0397 - root_mean_squared_error: 32.3859 - val_loss: 1800.6671 - val_root_mean_squared_error: 42.4343
# Epoch 69/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1017.5106 - root_mean_squared_error: 31.8491 - val_loss: 1764.2130 - val_root_mean_squared_error: 42.0025
# Epoch 70/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 903.9069 - root_mean_squared_error: 30.0119 - val_loss: 1768.9507 - val_root_mean_squared_error: 42.0589
# Epoch 71/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1109.9335 - root_mean_squared_error: 33.2364 - val_loss: 1715.5150 - val_root_mean_squared_error: 41.4188
# Epoch 72/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 947.4447 - root_mean_squared_error: 30.7400 - val_loss: 1671.7628 - val_root_mean_squared_error: 40.8872
# Epoch 73/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 996.2629 - root_mean_squared_error: 31.5255 - val_loss: 1630.1520 - val_root_mean_squared_error: 40.3751
# Epoch 74/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 880.1649 - root_mean_squared_error: 29.6127 - val_loss: 1614.4757 - val_root_mean_squared_error: 40.1805
# Epoch 75/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 848.6623 - root_mean_squared_error: 28.9781 - val_loss: 1594.7892 - val_root_mean_squared_error: 39.9348
# Epoch 76/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1016.8004 - root_mean_squared_error: 31.8642 - val_loss: 1566.2856 - val_root_mean_squared_error: 39.5763
# Epoch 77/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1090.5242 - root_mean_squared_error: 32.8319 - val_loss: 1547.4750 - val_root_mean_squared_error: 39.3380
# Epoch 78/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1058.5947 - root_mean_squared_error: 32.5081 - val_loss: 1536.5095 - val_root_mean_squared_error: 39.1983
# Epoch 79/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1069.1624 - root_mean_squared_error: 32.6138 - val_loss: 1510.1027 - val_root_mean_squared_error: 38.8600
# Epoch 80/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1025.4913 - root_mean_squared_error: 31.9472 - val_loss: 1500.7864 - val_root_mean_squared_error: 38.7400
# Epoch 81/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 935.3727 - root_mean_squared_error: 30.5474 - val_loss: 1484.4744 - val_root_mean_squared_error: 38.5289
# Epoch 82/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1131.9019 - root_mean_squared_error: 33.6139 - val_loss: 1462.5967 - val_root_mean_squared_error: 38.2439
# Epoch 83/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 987.3284 - root_mean_squared_error: 31.4031 - val_loss: 1422.6617 - val_root_mean_squared_error: 37.7182
# Epoch 84/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 966.0332 - root_mean_squared_error: 31.0496 - val_loss: 1442.6970 - val_root_mean_squared_error: 37.9829
# Epoch 85/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1084.0211 - root_mean_squared_error: 32.8065 - val_loss: 1397.5424 - val_root_mean_squared_error: 37.3837
# Epoch 86/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 987.1660 - root_mean_squared_error: 31.3805 - val_loss: 1397.4144 - val_root_mean_squared_error: 37.3820
# Epoch 87/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1042.2310 - root_mean_squared_error: 32.1720 - val_loss: 1399.0291 - val_root_mean_squared_error: 37.4036
# Epoch 88/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 956.1188 - root_mean_squared_error: 30.8750 - val_loss: 1446.0891 - val_root_mean_squared_error: 38.0275
# Epoch 89/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 988.2354 - root_mean_squared_error: 31.4166 - val_loss: 1364.0408 - val_root_mean_squared_error: 36.9329
# Epoch 90/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1042.6694 - root_mean_squared_error: 32.1569 - val_loss: 1344.0701 - val_root_mean_squared_error: 36.6616
# Epoch 91/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1083.5629 - root_mean_squared_error: 32.8751 - val_loss: 1382.8563 - val_root_mean_squared_error: 37.1868
# Epoch 92/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 937.9489 - root_mean_squared_error: 30.6000 - val_loss: 1317.6069 - val_root_mean_squared_error: 36.2989
# Epoch 93/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 923.8226 - root_mean_squared_error: 30.3577 - val_loss: 1334.0302 - val_root_mean_squared_error: 36.5244
# Epoch 94/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1041.5011 - root_mean_squared_error: 32.2130 - val_loss: 1337.0261 - val_root_mean_squared_error: 36.5654
# Epoch 95/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 968.9709 - root_mean_squared_error: 31.1106 - val_loss: 1303.4083 - val_root_mean_squared_error: 36.1027
# Epoch 96/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 895.8227 - root_mean_squared_error: 29.8771 - val_loss: 1284.4430 - val_root_mean_squared_error: 35.8391
# Epoch 97/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1016.7756 - root_mean_squared_error: 31.8386 - val_loss: 1311.0580 - val_root_mean_squared_error: 36.2085
# Epoch 98/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 986.7924 - root_mean_squared_error: 31.3743 - val_loss: 1278.4302 - val_root_mean_squared_error: 35.7551
# Epoch 99/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 874.8758 - root_mean_squared_error: 29.5190 - val_loss: 1269.1769 - val_root_mean_squared_error: 35.6255
# Epoch 100/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 935.3447 - root_mean_squared_error: 30.5417 - val_loss: 1288.0530 - val_root_mean_squared_error: 35.8895

# %%
from tensorflow.keras.models import load_model
model3 = load_model('/kaggle/working/model3.keras')

# %%
# Evaluate the model on the train data
train_result = model3.predict(X_train1)

# Calculate metrics
mse = mean_squared_error(y_train1, train_result)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_train1, train_result)
r2 = r2_score(y_train1, train_result)

# Print the results
print("Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (Accuracy): {r2:.4f}")
# Out:
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Evaluation Metrics:
# Mean Absolute Error (MAE): 18.1520
# Mean Squared Error (MSE): 951.7811
# Root Mean Squared Error (RMSE): 30.8509
# R-squared (Accuracy): 0.6986

# %%
# Evaluate the model on the validation data
val_result = model3.predict(X_val1)

# Calculate metrics
mse = mean_squared_error(y_val1, val_result)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_val1, val_result)
r2 = r2_score(y_val1, val_result)

# Print the results
print("Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (Accuracy): {r2:.4f}")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Evaluation Metrics:
# Mean Absolute Error (MAE): 26.2879
# Mean Squared Error (MSE): 1269.1769
# Root Mean Squared Error (RMSE): 35.6255
# R-squared (Accuracy): 0.7790

# %%
# Evaluate the model on the test data
test_result = model3.predict(X_test1)

# Calculate metrics
mse = mean_squared_error(y_test1, test_result)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test1, test_result)
r2 = r2_score(y_test1, test_result)

# Print the results
print("Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (Accuracy): {r2:.4f}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Evaluation Metrics:
# Mean Absolute Error (MAE): 19.7693
# Mean Squared Error (MSE): 685.0728
# Root Mean Squared Error (RMSE): 26.1739
# R-squared (Accuracy): 0.7584

# %%
train_predictions = model3.predict(X_train1).flatten()
train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_train1})
train_results
# Out:
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#       Train Predictions  Actuals
# 0            180.850891    195.0
# 1            190.580566    185.0
# 2            182.568619    208.0
# 3            209.236328    290.0
# 4            242.512390    267.0
# ...                 ...      ...
# 2228         214.577530    197.0
# 2229         200.027863    216.0
# 2230         223.202301    223.0
# 2231         218.743866    269.0
# 2232         240.888550    233.0
#
# [2233 rows x 2 columns]

# %%
plt.plot(train_results['Actuals'][1:50], label='Actual')
plt.plot(train_results['Train Predictions'][1:50], label='Predicted')
plt.legend()
plt.show()

# %%
val_predictions = model3.predict(X_val1).flatten()
val_results = pd.DataFrame(data={'Train Predictions':val_predictions, 'Actuals':y_val1})
val_results
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#      Train Predictions  Actuals
# 0           212.272614    183.0
# 1           192.796906    206.0
# 2           215.303421    189.0
# 3           193.291656    181.0
# 4           195.890244    189.0
# ..                 ...      ...
# 628         193.013199    193.0
# 629         221.395813    199.0
# 630         200.517197    197.0
# 631         214.711426    197.0
# 632         201.968246    190.0
#
# [633 rows x 2 columns]

# %%
plt.plot(val_results['Actuals'][1:50], label='Actual')
plt.plot(val_results['Train Predictions'][1:50], label='Predicted')
plt.legend()
plt.show()

# %%
test_predictions = model3.predict(X_test1).flatten()
test_results = pd.DataFrame(data={'Train Predictions':test_predictions, 'Actuals':y_test1})
test_results
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#      Train Predictions  Actuals
# 0           204.501938    190.0
# 1           194.707520    177.0
# 2           186.324722    172.0
# 3           175.680405    170.0
# 4           170.605743    197.0
# ..                 ...      ...
# 310         154.529953    134.0
# 311         137.427368    144.0
# 312         148.363693    155.0
# 313         150.681870    155.0
# 314         151.102325    152.0
#
# [315 rows x 2 columns]

# %%
plt.plot(test_results['Train Predictions'][1:50], label='Predicted')
plt.plot(test_results['Actuals'][1:50], label='Actual')
plt.legend()
plt.show()

# %% [markdown]
# # CNN+GRU

# %%
model4 = Sequential()

# Convolutional layer
model4.add(Conv1D(filters=128, kernel_size=3, activation='relu', input_shape=(X_train1.shape[1], 1)))

# GRU layer
model4.add(GRU(units=16, return_sequences=False))  # Return_sequences=False for final GRU layer

# Dense layers
model4.add(Dense(8, activation='relu'))
model4.add(Dropout(0.2)) 
model4.add(Dense(1, activation='linear'))

model4.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                      │ (None, 4, 128)              │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_1 (GRU)                          │ (None, 16)                  │           7,008 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 8)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,665 (29.94 KB)
#  Trainable params: 7,665 (29.94 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp4 = ModelCheckpoint('/kaggle/working/model4.keras', save_best_only=True)
model4.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0005), 
               metrics=[RootMeanSquaredError()])

# %%
model4.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), 
           epochs=100, callbacks=[cp4])
# Out:
# Epoch 1/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 28346.2070 - root_mean_squared_error: 168.3564 - val_loss: 33021.0820 - val_root_mean_squared_error: 181.7170
# Epoch 2/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27488.4180 - root_mean_squared_error: 165.7884 - val_loss: 32781.0312 - val_root_mean_squared_error: 181.0553
# Epoch 3/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27558.8223 - root_mean_squared_error: 165.9971 - val_loss: 32484.3477 - val_root_mean_squared_error: 180.2341
# Epoch 4/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27305.7969 - root_mean_squared_error: 165.2389 - val_loss: 32111.9453 - val_root_mean_squared_error: 179.1981
# Epoch 5/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 26884.3418 - root_mean_squared_error: 163.9542 - val_loss: 31721.0625 - val_root_mean_squared_error: 178.1041
# Epoch 6/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 26405.9688 - root_mean_squared_error: 162.4958 - val_loss: 31281.2988 - val_root_mean_squared_error: 176.8652
# Epoch 7/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25669.4980 - root_mean_squared_error: 160.2102 - val_loss: 30789.0840 - val_root_mean_squared_error: 175.4682
# Epoch 8/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25681.5742 - root_mean_squared_error: 160.2475 - val_loss: 30240.5938 - val_root_mean_squared_error: 173.8982
# Epoch 9/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 25894.2070 - root_mean_squared_error: 160.8550 - val_loss: 29661.4414 - val_root_mean_squared_error: 172.2250
# Epoch 10/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24047.0254 - root_mean_squared_error: 155.0573 - val_loss: 29032.9160 - val_root_mean_squared_error: 170.3905
# Epoch 11/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23848.7422 - root_mean_squared_error: 154.4074 - val_loss: 28374.3672 - val_root_mean_squared_error: 168.4469
# Epoch 12/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23255.3711 - root_mean_squared_error: 152.4873 - val_loss: 27681.7227 - val_root_mean_squared_error: 166.3783
# Epoch 13/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23201.6719 - root_mean_squared_error: 152.3054 - val_loss: 26945.3145 - val_root_mean_squared_error: 164.1503
# Epoch 14/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21848.2832 - root_mean_squared_error: 147.7925 - val_loss: 26192.6426 - val_root_mean_squared_error: 161.8414
# Epoch 15/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21583.5645 - root_mean_squared_error: 146.9067 - val_loss: 25426.6504 - val_root_mean_squared_error: 159.4574
# Epoch 16/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20051.3750 - root_mean_squared_error: 141.5800 - val_loss: 24645.1191 - val_root_mean_squared_error: 156.9876
# Epoch 17/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19884.5664 - root_mean_squared_error: 140.9716 - val_loss: 23848.0840 - val_root_mean_squared_error: 154.4283
# Epoch 18/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19820.1094 - root_mean_squared_error: 140.7582 - val_loss: 23047.7812 - val_root_mean_squared_error: 151.8150
# Epoch 19/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18447.3848 - root_mean_squared_error: 135.8115 - val_loss: 22238.2441 - val_root_mean_squared_error: 149.1249
# Epoch 20/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18341.1699 - root_mean_squared_error: 135.4138 - val_loss: 21439.0195 - val_root_mean_squared_error: 146.4207
# Epoch 21/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18085.3398 - root_mean_squared_error: 134.4086 - val_loss: 20628.7207 - val_root_mean_squared_error: 143.6270
# Epoch 22/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15944.9805 - root_mean_squared_error: 126.2671 - val_loss: 19835.6875 - val_root_mean_squared_error: 140.8392
# Epoch 23/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 
# Epoch 51/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6362.5181 - root_mean_squared_error: 79.6772 - val_loss: 6948.6484 - val_root_mean_squared_error: 83.3586
# Epoch 52/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5957.3101 - root_mean_squared_error: 77.1152 - val_loss: 6850.0029 - val_root_mean_squared_error: 82.7647
# Epoch 53/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5577.9033 - root_mean_squared_error: 74.6549 - val_loss: 6779.2139 - val_root_mean_squared_error: 82.3360
# Epoch 54/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6093.9639 - root_mean_squared_error: 78.0077 - val_loss: 6711.5728 - val_root_mean_squared_error: 81.9242
# Epoch 55/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5794.4829 - root_mean_squared_error: 76.0310 - val_loss: 6659.5879 - val_root_mean_squared_error: 81.6063
# Epoch 56/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6339.8403 - root_mean_squared_error: 79.5080 - val_loss: 6613.2139 - val_root_mean_squared_error: 81.3217
# Epoch 57/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5744.2510 - root_mean_squared_error: 75.7556 - val_loss: 6572.8130 - val_root_mean_squared_error: 81.0729
# Epoch 58/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5341.7827 - root_mean_squared_error: 73.0652 - val_loss: 6539.2261 - val_root_mean_squared_error: 80.8655
# Epoch 59/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6066.4849 - root_mean_squared_error: 77.8456 - val_loss: 6504.4399 - val_root_mean_squared_error: 80.6501
# Epoch 60/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6010.0708 - root_mean_squared_error: 77.5095 - val_loss: 6483.2690 - val_root_mean_squared_error: 80.5188
# Epoch 61/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6139.4360 - root_mean_squared_error: 78.3376 - val_loss: 6474.5146 - val_root_mean_squared_error: 80.4644
# Epoch 62/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5444.2422 - root_mean_squared_error: 73.7651 - val_loss: 6454.4414 - val_root_mean_squared_error: 80.3395
# Epoch 63/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5935.7578 - root_mean_squared_error: 77.0337 - val_loss: 6439.1743 - val_root_mean_squared_error: 80.2445
# Epoch 64/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5668.2178 - root_mean_squared_error: 75.2379 - val_loss: 6426.9287 - val_root_mean_squared_error: 80.1681
# Epoch 65/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5367.2520 - root_mean_squared_error: 73.2088 - val_loss: 6419.0918 - val_root_mean_squared_error: 80.1192
# Epoch 66/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5857.3369 - root_mean_squared_error: 76.5118 - val_loss: 6417.2764 - val_root_mean_squared_error: 80.1079
# Epoch 67/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5575.1870 - root_mean_squared_error: 74.6255 - val_loss: 6407.9253 - val_root_mean_squared_error: 80.0495
# Epoch 68/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5885.7236 - root_mean_squared_error: 76.6928 - val_loss: 6404.2539 - val_root_mean_squared_error: 80.0266
# Epoch 69/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5638.4780 - root_mean_squared_error: 75.0748 - val_loss: 6400.7017 - val_root_mean_squared_error: 80.0044
# Epoch 70/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6053.8438 - root_mean_squared_error: 77.7884 - val_loss: 6397.2881 - val_root_mean_squared_error: 79.9830
# Epoch 71/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5482.9546 - root_mean_squared_error: 73.9763 - val_loss: 6403.2598 - val_root_mean_squared_error: 80.0204
# Epoch 72/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5304.6758 - root_mean_squared_error: 72.8117 - val_loss: 6377.0381 - val_root_mean_squared_error: 79.8564
# Epoch 73/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5893.2852 - root_mean_squared_error: 76.7519 - val_loss: 6363.8853 - val_root_mean_squared_error: 79.7740
# Epoch 74/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5797.8247 - root_mean_squared_error: 76.1299 - val_loss: 6376.6328 - val_root_mean_squared_error: 79.8538
# Epoch 75/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5917.4727 - root_mean_squared_error: 76.8589 - val_loss: 6371.2153 - val_root_mean_squared_error: 79.8199
# Epoch 76/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6004.8096 - root_mean_squared_error: 77.4703 - val_loss: 6371.1621 - val_root_mean_squared_error: 79.8196
# Epoch 77/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6288.6567 - root_mean_squared_error: 79.2535 - val_loss: 6370.8237 - val_root_mean_squared_error: 79.8174
# Epoch 78/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5899.8750 - root_mean_squared_error: 76.7960 - val_loss: 6363.9702 - val_root_mean_squared_error: 79.7745
# Epoch 79/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6305.9561 - root_mean_squared_error: 79.3822 - val_loss: 6362.2217 - val_root_mean_squared_error: 79.7635
# Epoch 80/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6093.7852 - root_mean_squared_error: 78.0512 - val_loss: 6344.5298 - val_root_mean_squared_error: 79.6526
# Epoch 81/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5770.1909 - root_mean_squared_error: 75.9225 - val_loss: 6362.2671 - val_root_mean_squared_error: 79.7638
# Epoch 82/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5114.8511 - root_mean_squared_error: 71.4349 - val_loss: 6362.9722 - val_root_mean_squared_error: 79.7682
# Epoch 83/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5828.8252 - root_mean_squared_error: 76.2973 - val_loss: 6361.3540 - val_root_mean_squared_error: 79.7581
# Epoch 84/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5739.7822 - root_mean_squared_error: 75.7401 - val_loss: 6364.5918 - val_root_mean_squared_error: 79.7784
# Epoch 85/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6083.7051 - root_mean_squared_error: 77.9193 - val_loss: 6370.4976 - val_root_mean_squared_error: 79.8154
# Epoch 86/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5650.1460 - root_mean_squared_error: 75.1571 - val_loss: 6372.6670 - val_root_mean_squared_error: 79.8290
# Epoch 87/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5811.6489 - root_mean_squared_error: 76.2241 - val_loss: 6360.7188 - val_root_mean_squared_error: 79.7541
# Epoch 88/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6329.8848 - root_mean_squared_error: 79.4886 - val_loss: 6354.5918 - val_root_mean_squared_error: 79.7157
# Epoch 89/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5713.6260 - root_mean_squared_error: 75.5586 - val_loss: 7183.8877 - val_root_mean_squared_error: 84.7578
# Epoch 90/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6419.3467 - root_mean_squared_error: 80.0950 - val_loss: 6926.6807 - val_root_mean_squared_error: 83.2267
# Epoch 91/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6023.8643 - root_mean_squared_error: 77.5854 - val_loss: 6744.5996 - val_root_mean_squared_error: 82.1255
# Epoch 92/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6104.5059 - root_mean_squared_error: 78.1046 - val_loss: 6628.4463 - val_root_mean_squared_error: 81.4153
# Epoch 93/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5770.5186 - root_mean_squared_error: 75.9167 - val_loss: 6539.2236 - val_root_mean_squared_error: 80.8655
# Epoch 94/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5527.8677 - root_mean_squared_error: 74.2427 - val_loss: 6483.7505 - val_root_mean_squared_error: 80.5217
# Epoch 95/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5443.9375 - root_mean_squared_error: 73.7676 - val_loss: 6445.9985 - val_root_mean_squared_error: 80.2870
# Epoch 96/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6221.9683 - root_mean_squared_error: 78.8706 - val_loss: 6413.3340 - val_root_mean_squared_error: 80.0833
# Epoch 97/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6007.0757 - root_mean_squared_error: 77.4873 - val_loss: 6402.5156 - val_root_mean_squared_error: 80.0157
# Epoch 98/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5850.4097 - root_mean_squared_error: 76.4435 - val_loss: 6377.5703 - val_root_mean_squared_error: 79.8597
# Epoch 99/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5908.9658 - root_mean_squared_error: 76.7979 - val_loss: 6394.0200 - val_root_mean_squared_error: 79.9626
# Epoch 100/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5970.7593 - root_mean_squared_error: 77.2518 - val_loss: 6412.4688 - val_root_mean_squared_error: 80.0779

# %%
from tensorflow.keras.models import load_model
model4 = load_model('/kaggle/working/model4.keras')

# %%
# Evaluate the model on the train data
train_result = model4.predict(X_train1)

# Calculate metrics
mse = mean_squared_error(y_train1, train_result)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_train1, train_result)
r2 = r2_score(y_train1, train_result)

# Print the results
print("Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (Accuracy): {r2:.4f}")
# Out:
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Evaluation Metrics:
# Mean Absolute Error (MAE): 44.8496
# Mean Squared Error (MSE): 3461.1576
# Root Mean Squared Error (RMSE): 58.8316
# R-squared (Accuracy): -0.0959

# %%
# Evaluate the model on the validation data
val_result = model4.predict(X_val1)

# Calculate metrics
mse = mean_squared_error(y_val1, val_result)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_val1, val_result)
r2 = r2_score(y_val1, val_result)

# Print the results
print("Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (Accuracy): {r2:.4f}")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Evaluation Metrics:
# Mean Absolute Error (MAE): 61.0953
# Mean Squared Error (MSE): 6344.5301
# Root Mean Squared Error (RMSE): 79.6526
# R-squared (Accuracy): -0.1047

# %%
# Evaluate the model on the test data
test_result = model4.predict(X_test1)

# Calculate metrics
mse = mean_squared_error(y_test1, test_result)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test1, test_result)
r2 = r2_score(y_test1, test_result)

# Print the results
print("Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (Accuracy): {r2:.4f}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Evaluation Metrics:
# Mean Absolute Error (MAE): 43.0662
# Mean Squared Error (MSE): 2836.4852
# Root Mean Squared Error (RMSE): 53.2587
# R-squared (Accuracy): -0.0001
