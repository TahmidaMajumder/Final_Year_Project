# %%
# Packages / libraries
import os #provides functions for interacting with the operating system
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# remove warnings
import warnings
warnings.simplefilter(action='ignore', category=RuntimeWarning)

# %% [markdown]
# # **1. Loading Dataset**

# %%
# Loading the data
new_data = pd.read_csv("/kaggle/input/seperated-data/India_Delhi.csv")

# print the shape
print(new_data.shape)

#runs the first 5 rows
new_data.head()
# Out:
# (2399, 12)
#          Date    co   no2   o3   pm10   pm25  so2  humidity  pressure  \
# 0  2014-12-29  14.1  36.2  3.2  218.0  307.0  4.2       NaN       NaN
# 1  2014-12-30  20.4  36.8  4.8  330.0  367.0  5.8       NaN       NaN
# 2  2014-12-31  12.7  28.7  7.8  137.0  202.0  6.3       NaN       NaN
# 3  2015-01-01  20.8  66.5  5.2  230.0  382.0  9.9       NaN       NaN
# 4  2015-01-02  12.7  33.9  6.0   81.0  172.0  4.2       NaN       NaN
#
#    temperature  wind-speed Country_City
# 0          NaN         NaN  India_Delhi
# 1          NaN         NaN  India_Delhi
# 2          NaN         NaN  India_Delhi
# 3          NaN         NaN  India_Delhi
# 4          NaN         NaN  India_Delhi

# %%
# Find the minimum and maximum dates
min_date = new_data['Date'].min()
max_date = new_data['Date'].max()

print('Minimum date:', min_date)
print('Maximum date:', max_date)
# Out:
# Minimum date: 2014-12-29
# Maximum date: 2023-10-01

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2399 entries, 0 to 2398
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          2399 non-null   object
#  1   co            2399 non-null   float64
#  2   no2           2399 non-null   float64
#  3   o3            2399 non-null   float64
#  4   pm10          2398 non-null   float64
#  5   pm25          2398 non-null   float64
#  6   so2           2399 non-null   float64
#  7   humidity      1698 non-null   float64
#  8   pressure      1698 non-null   float64
#  9   temperature   1698 non-null   float64
#  10  wind-speed    1629 non-null   float64
#  11  Country_City  2399 non-null   object
# dtypes: float64(10), object(2)
# memory usage: 225.0+ KB

# %%
new_data.describe()
# Out:
#                 co          no2           o3         pm10         pm25  \
# count  2399.000000  2399.000000  2399.000000  2398.000000  2398.000000
# mean      9.325594    16.870946     9.480700   131.572143   164.397832
# std       3.715709     7.805715     4.829603    77.174642    64.829240
# min       0.100000     5.000000     2.400000    12.000000    30.000000
# 25%       7.050000    10.600000     6.000000    82.000000   123.000000
# 50%       8.400000    15.800000     8.200000   120.000000   160.000000
# 75%      10.700000    21.500000    11.800000   160.000000   189.000000
# max      30.600000    66.500000    40.300000   999.000000   577.000000
#
#                so2     humidity     pressure  temperature   wind-speed
# count  2399.000000  1698.000000  1698.000000  1698.000000  1629.000000
# mean      5.702751    60.708304   985.184923    26.338869     1.101964
# std       2.289821    17.138084    10.022854     6.631277     0.493156
# min       1.700000    13.000000   743.000000     6.200000     0.300000
# 25%       4.000000    48.500000   979.800000    22.100000     0.800000
# 50%       5.300000    63.000000   983.900000    28.600000     1.000000
# 75%       7.100000    74.000000   990.400000    31.100000     1.300000
# max      19.800000    99.100000  1020.500000    38.000000     4.600000

# %%
# Investigate all the elements whithin each Feature

for column in new_data:
    # Handle numerical and string columns differently
    if new_data[column].dtype == 'object':  # Check if column is of object type
        unique_vals = new_data[column].unique()  # pandas unique for strings
    else:
        unique_vals = np.unique(new_data[column])  # numpy unique for numerical types

    nr_values = len(unique_vals)
    if nr_values < 14:
        print('The number of values for feature {} :{} -- {}'.format(column, nr_values,unique_vals))
    else:
        print('The number of values for feature {} :{}'.format(column, nr_values))
# Out:
# The number of values for feature Date :2397
# The number of values for feature co :200
# The number of values for feature no2 :328
# The number of values for feature o3 :226
# The number of values for feature pm10 :320
# The number of values for feature pm25 :309
# The number of values for feature so2 :116
# The number of values for feature humidity :602
# The number of values for feature pressure :300
# The number of values for feature temperature :264
# The number of values for feature wind-speed :33
# The number of values for feature Country_City :1 -- ['India_Delhi']

# %%
new_data.isna().sum()
# Out:
# Date              0
# co                0
# no2               0
# o3                0
# pm10              1
# pm25              1
# so2               0
# humidity        701
# pressure        701
# temperature     701
# wind-speed      770
# Country_City      0
# dtype: int64

# %% [markdown]
# # **1.2 - Function**

# %%
print(os.listdir('/kaggle/usr/lib/function'))
# Out:
# ['__script__.py', '__results__.html', '__script__.ipynb', 'function.py', '__output__.json', 'custom.css']

# %%
import sys
sys.path.append("/kaggle/usr/lib/function")  # Add directory to the path

import function as fn

# %%
# Use the functions
new_data1 = fn.prepare_datetime_index(new_data, date_column='Date')
new_data1.head()
# Out:
#               co   no2   o3   pm10   pm25  so2  humidity  pressure  \
# Date
# 2014-12-29  14.1  36.2  3.2  218.0  307.0  4.2       NaN       NaN
# 2014-12-30  20.4  36.8  4.8  330.0  367.0  5.8       NaN       NaN
# 2014-12-31  12.7  28.7  7.8  137.0  202.0  6.3       NaN       NaN
# 2015-01-01  20.8  66.5  5.2  230.0  382.0  9.9       NaN       NaN
# 2015-01-02  12.7  33.9  6.0   81.0  172.0  4.2       NaN       NaN
#
#             temperature  wind-speed Country_City
# Date
# 2014-12-29          NaN         NaN  India_Delhi
# 2014-12-30          NaN         NaN  India_Delhi
# 2014-12-31          NaN         NaN  India_Delhi
# 2015-01-01          NaN         NaN  India_Delhi
# 2015-01-02          NaN         NaN  India_Delhi

# %%
# Use the functions
new_data2 = fn.fill_pollutant_values(new_data1)
print(new_data2.isna().sum())
# Out:
# co              0
# no2             0
# o3              0
# pm10            0
# pm25            0
# so2             0
# humidity        0
# pressure        0
# temperature     0
# wind-speed      0
# Country_City    0
# dtype: int64

# %% [markdown]
# **Check**

# %%
# Create a complete range of dates
full_range = pd.date_range(start=new_data2.index.min(), end=new_data2.index.max())

# Find missing dates
missing_dates = full_range.difference(new_data2.index)
print("Missing Dates:")
print(missing_dates)
# Out:
# Missing Dates:
# DatetimeIndex(['2015-07-06', '2015-07-07', '2015-07-08', '2015-07-09',
#                '2015-07-10', '2015-07-11', '2015-07-12', '2015-07-13',
#                '2015-07-14', '2015-07-15',
#                ...
#                '2022-03-18', '2022-03-19', '2022-03-20', '2022-03-21',
#                '2022-03-22', '2022-03-23', '2022-03-24', '2022-03-25',
#                '2022-03-26', '2022-03-27'],
#               dtype='datetime64[ns]', length=802, freq=None)

# %%
new_data3 = fn.impute_missing_dates(new_data2)

# %%
# Create a complete range of dates
full_range = pd.date_range(start=new_data3.index.min(), end=new_data3.index.max())

# Find missing dates
missing_dates = full_range.difference(new_data3.index)
print("Missing Dates:")
print(missing_dates)
# Out:
# Missing Dates:
# DatetimeIndex([], dtype='datetime64[ns]', freq='D')

# %%
duplicates = new_data3.index[new_data3.index.duplicated()]
print(f"Duplicate indexes: {duplicates}")
# Out:
# Duplicate indexes: DatetimeIndex([], dtype='datetime64[ns]', freq='D')

# %% [markdown]
# # **1.3.Normal AQI count, After Normal AQI count Smoothing AQI(IQR, Z-score, Rolling), (Preprocess Pollution --> Smooth Pollution --> Calculate smooth aqi).**

# %%
new_data4 = fn.calculate_aqi(new_data3, subindex_columns=['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'])

# %%
new_data4.head()
# Out:
#               co   no2   o3   pm10   pm25  so2   humidity    pressure  \
# 2014-12-29  14.1  36.2  3.2  218.0  307.0  4.2  60.691097  985.187382
# 2014-12-30  20.4  36.8  4.8  330.0  367.0  5.8  60.691097  985.187382
# 2014-12-31  12.7  28.7  7.8  137.0  202.0  6.3  60.691097  985.187382
# 2015-01-01  20.8  66.5  5.2  230.0  382.0  9.9  60.691097  985.187382
# 2015-01-02  12.7  33.9  6.0   81.0  172.0  4.2  60.691097  985.187382
#
#             temperature  wind-speed Country_City  Checks    AQI
# 2014-12-29      26.3352    1.102459  India_Delhi       6  307.0
# 2014-12-30      26.3352    1.102459  India_Delhi       6  367.0
# 2014-12-31      26.3352    1.102459  India_Delhi       6  202.0
# 2015-01-01      26.3352    1.102459  India_Delhi       6  382.0
# 2015-01-02      26.3352    1.102459  India_Delhi       6  172.0

# %%
new_data4.shape
# Out:
# (3199, 13)

# %% [markdown]
#  After Normal AQI count Smoothing AQI(IQR, Z-score, Rolling)

# %%
# Apply the outlier handling function to the 'AQI' column only
new_data4['AQI_smoothed_iqr'] = fn.handle_aqi_outliers(new_data4['AQI'], method='iqr')
new_data4['AQI_smoothed_zscore'] = fn.handle_aqi_outliers(new_data4['AQI'], method='zscore')
new_data4['AQI_smoothed_rolling'] = fn.handle_aqi_outliers(new_data4['AQI'], method='rolling')

# %%
new_data4.head()
# Out:
#               co   no2   o3   pm10   pm25  so2   humidity    pressure  \
# 2014-12-29  14.1  36.2  3.2  218.0  307.0  4.2  60.691097  985.187382
# 2014-12-30  20.4  36.8  4.8  330.0  367.0  5.8  60.691097  985.187382
# 2014-12-31  12.7  28.7  7.8  137.0  202.0  6.3  60.691097  985.187382
# 2015-01-01  20.8  66.5  5.2  230.0  382.0  9.9  60.691097  985.187382
# 2015-01-02  12.7  33.9  6.0   81.0  172.0  4.2  60.691097  985.187382
#
#             temperature  wind-speed Country_City  Checks    AQI  \
# 2014-12-29      26.3352    1.102459  India_Delhi       6  307.0
# 2014-12-30      26.3352    1.102459  India_Delhi       6  367.0
# 2014-12-31      26.3352    1.102459  India_Delhi       6  202.0
# 2015-01-01      26.3352    1.102459  India_Delhi       6  382.0
# 2015-01-02      26.3352    1.102459  India_Delhi       6  172.0
#
#             AQI_smoothed_iqr  AQI_smoothed_zscore  AQI_smoothed_rolling
# 2014-12-29             307.0                307.0                 307.0
# 2014-12-30             367.0                367.0                 367.0
# 2014-12-31             202.0                202.0                 202.0
# 2015-01-01             382.0                158.0                 382.0
# 2015-01-02             172.0                172.0                 172.0

# %% [markdown]
# (Preprocess Pollution --> Smooth Pollution --> Calculate smooth aqi)

# %%
new_smooth = fn.calculate_smooth_aqi(new_data3, columns=['co', 'no2', 'o3', 'pm10', 'pm25', 'so2'])
new_smooth.head()
# Out:
#                co        no2        o3        pm10        pm25       so2  \
# 2014-12-29  15.70  35.883333  5.366667  182.333333  268.166667  6.000000
# 2014-12-30  15.70  35.883333  5.366667  182.333333  268.166667  6.000000
# 2014-12-31  15.70  35.883333  5.366667  182.333333  268.166667  6.000000
# 2015-01-01  15.70  35.883333  5.366667  182.333333  268.166667  6.000000
# 2015-01-02  15.45  33.100000  5.816667  166.000000  249.500000  5.733333
#
#              humidity    pressure  temperature  wind-speed Country_City  \
# 2014-12-29  60.691097  985.187382      26.3352    1.102459  India_Delhi
# 2014-12-30  60.691097  985.187382      26.3352    1.102459  India_Delhi
# 2014-12-31  60.691097  985.187382      26.3352    1.102459  India_Delhi
# 2015-01-01  60.691097  985.187382      26.3352    1.102459  India_Delhi
# 2015-01-02  60.691097  985.187382      26.3352    1.102459  India_Delhi
#
#             AQI_Smooth
# 2014-12-29  268.166667
# 2014-12-30  268.166667
# 2014-12-31  268.166667
# 2015-01-01  268.166667
# 2015-01-02  249.500000

# %% [markdown]
# **AQI (normal, smooth_iqr, smooth_zscore, smooth_rolling, smooth)**

# %%
#normal
aqi_normal = new_data4['AQI']
aqi_normal.plot()
# Out:
# <Axes: >

# %%
#smooth_iqr
aqi_smooth_iqr = new_data4['AQI_smoothed_iqr']
aqi_smooth_iqr.plot()
# Out:
# <Axes: >

# %%
#smooth_zscore
aqi_smooth_zscore = new_data4['AQI_smoothed_zscore']
aqi_smooth_zscore.plot()
# Out:
# <Axes: >

# %%
#smooth_rolling
aqi_smooth_rolling = new_data4['AQI_smoothed_rolling']
aqi_smooth_rolling.plot()
# Out:
# <Axes: >

# %%
#smooth
aqi_smooth = new_smooth['AQI_Smooth']
aqi_smooth.plot()
# Out:
# <Axes: >

# %% [markdown]
# # **2.1. Splitting & Preprocessing the Raw Data(AQI_smoothed_rolling)**

# %% [markdown]
# AQI_smoothed_rolling

# %%
new_data4.head(8)
# Out:
#               co   no2   o3   pm10   pm25  so2   humidity    pressure  \
# 2014-12-29  14.1  36.2  3.2  218.0  307.0  4.2  60.691097  985.187382
# 2014-12-30  20.4  36.8  4.8  330.0  367.0  5.8  60.691097  985.187382
# 2014-12-31  12.7  28.7  7.8  137.0  202.0  6.3  60.691097  985.187382
# 2015-01-01  20.8  66.5  5.2  230.0  382.0  9.9  60.691097  985.187382
# 2015-01-02  12.7  33.9  6.0   81.0  172.0  4.2  60.691097  985.187382
# 2015-01-03  14.3  27.8  5.2   98.0  179.0  5.6  60.691097  985.187382
# 2015-01-04  12.6  19.5  5.9  120.0  195.0  2.6  60.691097  985.187382
# 2015-01-05  13.1  19.1  8.4  114.0  185.0  2.5  60.691097  985.187382
#
#             temperature  wind-speed Country_City  Checks    AQI  \
# 2014-12-29      26.3352    1.102459  India_Delhi       6  307.0
# 2014-12-30      26.3352    1.102459  India_Delhi       6  367.0
# 2014-12-31      26.3352    1.102459  India_Delhi       6  202.0
# 2015-01-01      26.3352    1.102459  India_Delhi       6  382.0
# 2015-01-02      26.3352    1.102459  India_Delhi       6  172.0
# 2015-01-03      26.3352    1.102459  India_Delhi       6  179.0
# 2015-01-04      26.3352    1.102459  India_Delhi       6  195.0
# 2015-01-05      26.3352    1.102459  India_Delhi       6  185.0
#
#             AQI_smoothed_iqr  AQI_smoothed_zscore  AQI_smoothed_rolling
# 2014-12-29             307.0                307.0                 307.0
# 2014-12-30             367.0                367.0                 367.0
# 2014-12-31             202.0                202.0                 202.0
# 2015-01-01             382.0                158.0                 382.0
# 2015-01-02             172.0                172.0                 172.0
# 2015-01-03             179.0                179.0                 179.0
# 2015-01-04             195.0                195.0                 195.0
# 2015-01-05             185.0                185.0                 185.0

# %%
new_data4.columns
# Out:
# Index(['co', 'no2', 'o3', 'pm10', 'pm25', 'so2', 'humidity', 'pressure',
#        'temperature', 'wind-speed', 'Country_City', 'Checks', 'AQI',
#        'AQI_smoothed_iqr', 'AQI_smoothed_zscore', 'AQI_smoothed_rolling'],
#       dtype='object')

# %% [markdown]
# ***Working with aqi_smooth_rolling***

# %%
aqi_smooth_rolling
# Out:
# 2014-12-29    307.0
# 2014-12-30    367.0
# 2014-12-31    202.0
# 2015-01-01    382.0
# 2015-01-02    172.0
#               ...
# 2023-09-27    134.0
# 2023-09-28    144.0
# 2023-09-29    155.0
# 2023-09-30    155.0
# 2023-10-01    152.0
# Freq: D, Name: AQI_smoothed_rolling, Length: 3199, dtype: float64

# %%
# Function to define window_size and convert data into X (features) and y (labels)
def new_data_to_X_y(new_data, window_size, train_pct, val_pct, test_pct):
    # Convert data to numpy array
    new_data_as_np = new_data.to_numpy()
    
    # Split data based on percentages
    total_len = len(new_data_as_np)
    train_end = int(train_pct * total_len)
    val_end = train_end + int(val_pct * total_len)
    
    # Prepare train, val, and test splits
    train_data = new_data_as_np[:train_end]
    val_data = new_data_as_np[train_end:val_end]
    test_data = new_data_as_np[val_end:]
    
    # Helper function to create X and y
    def create_X_y(data):
        X, y = [], []
        for i in range(len(data) - window_size):
            row = [[a] for a in data[i:i + window_size]]
            X.append(row)
            label = data[i + window_size]
            y.append(label)
        return np.array(X), np.array(y)
    
    # Create X and y for train, validation, and test
    X_train, y_train = create_X_y(train_data)
    X_val, y_val = create_X_y(val_data)
    X_test, y_test = create_X_y(test_data)
    
    return (X_train, y_train), (X_val, y_val), (X_test, y_test)

# %%
#passing data to function

# WINDOW_SIZE = 6
# train_pct=0.7
# val_pct=0.2
# test_pct=0.1
(X_train1, y_train1), (X_val1, y_val1), (X_test1, y_test1) = new_data_to_X_y(aqi_smooth_rolling, 6, 0.7, 0.2, 0.1)

# shapes
print("Train shapes:", X_train1.shape, y_train1.shape)
print("Validation shapes:", X_val1.shape, y_val1.shape)
print("Test shapes:", X_test1.shape, y_test1.shape)
# Out:
# Train shapes: (2233, 6, 1) (2233,)
# Validation shapes: (633, 6, 1) (633,)
# Test shapes: (315, 6, 1) (315,)

# %% [markdown]
# # **2.2. Model Training & Testing**

# %%
# libraries for building model and testing
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.losses import MeanSquaredError, MeanAbsoluteError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
from keras.regularizers import l2
from keras.callbacks import EarlyStopping

# %% [markdown]
# # LSTM-32-8(aqi_smooth_rolling)

# %%
model1 = Sequential()
model1.add(InputLayer((6, 1))) # 6 timestamp , 1 feature
model1.add(LSTM(32)) # LSTM layer with 16 units
model1.add(Dense(8, activation='relu')) # activation function- ReLU with 8 dense layer

model1.add(Dense(1, 'linear')) # output - linear and data- 1

model1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 32)                  │           4,352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 8)                   │             264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,625 (18.07 KB)
#  Trainable params: 4,625 (18.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp1 = ModelCheckpoint('/kaggle/working/model1.keras', save_best_only=True)

model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0005), 
               metrics=[RootMeanSquaredError()])

# %%
model1.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=100, 
           callbacks=[cp1])
# Out:
# Epoch 1/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 30390.2227 - root_mean_squared_error: 174.2652 - val_loss: 34574.1680 - val_root_mean_squared_error: 185.9413
# Epoch 2/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31559.7969 - root_mean_squared_error: 177.6268 - val_loss: 33995.1914 - val_root_mean_squared_error: 184.3779
# Epoch 3/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29448.6836 - root_mean_squared_error: 171.5829 - val_loss: 33103.7422 - val_root_mean_squared_error: 181.9443
# Epoch 4/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30775.5293 - root_mean_squared_error: 175.4116 - val_loss: 32234.3848 - val_root_mean_squared_error: 179.5394
# Epoch 5/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30218.8848 - root_mean_squared_error: 173.5780 - val_loss: 31178.4766 - val_root_mean_squared_error: 176.5743
# Epoch 6/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27249.4062 - root_mean_squared_error: 165.0612 - val_loss: 29797.3105 - val_root_mean_squared_error: 172.6190
# Epoch 7/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 26731.2285 - root_mean_squared_error: 163.4524 - val_loss: 28331.5957 - val_root_mean_squared_error: 168.3199
# Epoch 8/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 25114.9277 - root_mean_squared_error: 158.4584 - val_loss: 27026.2695 - val_root_mean_squared_error: 164.3967
# Epoch 9/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 24249.1445 - root_mean_squared_error: 155.6356 - val_loss: 25543.1797 - val_root_mean_squared_error: 159.8223
# Epoch 10/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22243.0918 - root_mean_squared_error: 149.1308 - val_loss: 24206.3008 - val_root_mean_squared_error: 155.5837
# Epoch 11/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20810.0332 - root_mean_squared_error: 144.2087 - val_loss: 22768.5625 - val_root_mean_squared_error: 150.8925
# Epoch 12/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20927.1230 - root_mean_squared_error: 144.5141 - val_loss: 21325.7637 - val_root_mean_squared_error: 146.0334
# Epoch 13/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18572.8867 - root_mean_squared_error: 136.2646 - val_loss: 19981.7949 - val_root_mean_squared_error: 141.3570
# Epoch 14/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17279.2051 - root_mean_squared_error: 131.4116 - val_loss: 18552.1777 - val_root_mean_squared_error: 136.2064
# Epoch 15/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15857.0469 - root_mean_squared_error: 125.8693 - val_loss: 17189.3105 - val_root_mean_squared_error: 131.1080
# Epoch 16/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14430.8281 - root_mean_squared_error: 119.9559 - val_loss: 15756.4277 - val_root_mean_squared_error: 125.5246
# Epoch 17/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13159.2070 - root_mean_squared_error: 114.5635 - val_loss: 14528.3711 - val_root_mean_squared_error: 120.5337
# Epoch 18/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11533.6963 - root_mean_squared_error: 107.3191 - val_loss: 13439.2197 - val_root_mean_squared_error: 115.9277
# Epoch 19/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11182.5430 - root_mean_squared_error: 105.7128 - val_loss: 12441.5908 - val_root_mean_squared_error: 111.5419
# Epoch 20/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10711.7568 - root_mean_squared_error: 103.3907 - val_loss: 11543.7617 - val_root_mean_squared_error: 107.4419
# Epoch 21/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9418.6348 - root_mean_squared_error: 96.9722 - val_loss: 10725.5381 - val_root_mean_squared_error: 103.5642
# Epoch 22/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8713.7451 - root_mean_squared_error: 93.3171 - val_loss: 9974.8037 - val_root_mean_squared_error: 99.8739
# Epoch 23/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7651.7080 - root_mean_squared_error: 87.4095 - val_loss: 9283.1133 - val_root_mean_squared_error: 96.3489
# Epoch 24/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7655.6846 - root_mean_squared_error: 87.3687 - val_loss: 8624.9990 - val_root_mean_squared_error: 92.8709
# Epoch 25/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7781.1636 - root_mean_squared_error: 88.1009 - val_loss: 8016.2900 - val_root_mean_squared_error: 89.5337
# Epoch 26/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5945.1768 - root_mean_squared_error: 76.9604 - val_loss: 7455.7979 - val_root_mean_squared_error: 86.3470
# Epoch 27/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6007.4214 - root_mean_squared_error: 77.3410 - val_loss: 6940.5283 - val_root_mean_squared_error: 83.3098
# Epoch 28/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5144.1997 - root_mean_squared_error: 71.5651 - val_loss: 6476.1382 - val_root_mean_squared_error: 80.4745
# Epoch 29/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5074.0928 - root_mean_squared_error: 71.1337 - val_loss: 6065.9824 - val_root_mean_squared_error: 77.8844
# Epoch 30/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5002.8496 - root_mean_squared_error: 70.6325 - val_loss: 5684.1187 - val_root_mean_squared_error: 75.3931
# Epoch 31/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4540.7832 - root_mean_squared_error: 67.3131 - val_loss: 5267.5732 - val_root_mean_squared_error: 72.5780
# Epoch 32/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3911.1907 - root_mean_squared_error: 62.4399 - val_loss: 4949.8662 - val_root_mean_squared_error: 70.3553
# Epoch 33/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3391.6667 - root_mean_squared_error: 58.0416 - val_loss: 4665.5439 - val_root_mean_squared_error: 68.3048
# Epoch 34/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3374.7400 - root_mean_squared_error: 57.9236 - val_loss: 4405.4502 - val_root_mean_squared_error: 66.3736
# Epoch 35/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4350.9829 - root_mean_squared_error: 65.2713 - val_loss: 4165.7529 - val_root_mean_squared_error: 64.5426
# Epoch 36/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3435.2896 - root_mean_squared_error: 58.5614 - val_loss: 3959.5493 - val_root_mean_squared_error: 62.9249
# Epoch 37/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3260.9019 - root_mean_squared_error: 57.0569 - val_loss: 3773.8696 - val_root_mean_squared_error: 61.4318
# Epoch 38/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2868.2117 - root_mean_squared_error: 53.4991 - val_loss: 3599.9529 - val_root_mean_squared_error: 59.9996
# Epoch 39/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3676.7056 - root_mean_squared_error: 60.1334 - val_loss: 3414.8057 - val_root_mean_squared_error: 58.4363
# Epoch 40/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2465.4272 - root_mean_squared_error: 49.1398 - val_loss: 3281.6553 - val_root_mean_squared_error: 57.2857
# Epoch 41/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2768.0610 - root_mean_squared_error: 52.4656 - val_loss: 3112.1199 - val_root_mean_squared_error: 55.7864
# Epoch 42/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3361.5615 - root_mean_squared_error: 57.1718 - val_loss: 2965.0884 - val_root_mean_squared_error: 54.4526
# Epoch 43/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2206.1687 - root_mean_squared_error: 46.3373 - val_loss: 2803.7588 - val_root_mean_squared_error: 52.9505
# Epoch 44/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2345.9050 - root_mean_squared_error: 48.2387 - val_loss: 2701.2766 - val_root_mean_squared_error: 51.9738
# Epoch 45/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2673.3796 - root_mean_squared_error: 51.6205 - val_loss: 2567.1052 - val_root_mean_squared_error: 50.6666
# Epoch 46/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2784.1384 - root_mean_squared_error: 52.3393 - val_loss: 2441.8125 - val_root_mean_squared_error: 49.4147
# Epoch 47/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2724.0227 - root_mean_squared_error: 51.8495 - val_loss: 2342.1682 - val_root_mean_squared_error: 48.3960
# Epoch 48/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2045.8164 - root_mean_squared_error: 45.0407 - val_loss: 2235.9258 - val_root_mean_squared_error: 47.2856
# Epoch 49/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2827.6106 - root_mean_squared_error: 53.0328 - val_loss: 2130.1699 - val_root_mean_squared_error: 46.1538
# Epoch 50/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2193.5769 - root_mean_squared_error: 46.7061 - val_loss: 2070.4216 - val_root_mean_squared_error: 45.5019
# Epoch 51/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2155.8140 - root_mean_squared_error: 46.3415 - val_loss: 1975.6056 - val_root_mean_squared_error: 44.4478
# Epoch 52/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2740.4150 - root_mean_squared_error: 52.0479 - val_loss: 1888.2356 - val_root_mean_squared_error: 43.4538
# Epoch 53/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2706.8237 - root_mean_squared_error: 51.7146 - val_loss: 1818.0798 - val_root_mean_squared_error: 42.6389
# Epoch 54/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1849.7795 - root_mean_squared_error: 42.7951 - val_loss: 1784.9769 - val_root_mean_squared_error: 42.2490
# Epoch 55/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1647.7349 - root_mean_squared_error: 40.2291 - val_loss: 1703.0442 - val_root_mean_squared_error: 41.2680
# Epoch 56/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2041.0305 - root_mean_squared_error: 44.8966 - val_loss: 1621.8827 - val_root_mean_squared_error: 40.2726
# Epoch 57/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2197.4634 - root_mean_squared_error: 46.7123 - val_loss: 1577.8416 - val_root_mean_squared_error: 39.7221
# Epoch 58/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1381.6487 - root_mean_squared_error: 36.7772 - val_loss: 1540.8760 - val_root_mean_squared_error: 39.2540
# Epoch 59/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2379.6462 - root_mean_squared_error: 48.5404 - val_loss: 1492.5592 - val_root_mean_squared_error: 38.6337
# Epoch 60/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1650.9012 - root_mean_squared_error: 40.4458 - val_loss: 1451.8264 - val_root_mean_squared_error: 38.1028
# Epoch 61/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2161.8621 - root_mean_squared_error: 46.3463 - val_loss: 1385.0154 - val_root_mean_squared_error: 37.2158
# Epoch 62/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1900.2015 - root_mean_squared_error: 43.3672 - val_loss: 1353.9562 - val_root_mean_squared_error: 36.7961
# Epoch 63/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1580.1749 - root_mean_squared_error: 39.5378 - val_loss: 1329.2338 - val_root_mean_squared_error: 36.4587
# Epoch 64/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1958.7223 - root_mean_squared_error: 43.9872 - val_loss: 1297.3391 - val_root_mean_squared_error: 36.0186
# Epoch 65/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2409.2327 - root_mean_squared_error: 48.6544 - val_loss: 1268.6830 - val_root_mean_squared_error: 35.6186
# Epoch 66/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1697.7317 - root_mean_squared_error: 41.1140 - val_loss: 1264.5421 - val_root_mean_squared_error: 35.5604
# Epoch 67/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1400.7078 - root_mean_squared_error: 37.1108 - val_loss: 1228.0876 - val_root_mean_squared_error: 35.0441
# Epoch 68/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1908.1327 - root_mean_squared_error: 43.4286 - val_loss: 1205.5217 - val_root_mean_squared_error: 34.7206
# Epoch 69/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2370.9224 - root_mean_squared_error: 48.4644 - val_loss: 1183.3019 - val_root_mean_squared_error: 34.3992
# Epoch 70/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1712.0494 - root_mean_squared_error: 41.2424 - val_loss: 1164.3351 - val_root_mean_squared_error: 34.1224
# Epoch 71/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2301.2188 - root_mean_squared_error: 47.2919 - val_loss: 1147.0940 - val_root_mean_squared_error: 33.8688
# Epoch 72/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1860.7583 - root_mean_squared_error: 43.0557 - val_loss: 1134.4857 - val_root_mean_squared_error: 33.6821
# Epoch 73/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1561.1079 - root_mean_squared_error: 39.1074 - val_loss: 1134.1267 - val_root_mean_squared_error: 33.6768
# Epoch 74/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1431.8916 - root_mean_squared_error: 37.5617 - val_loss: 1122.8412 - val_root_mean_squared_error: 33.5088
# Epoch 75/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2328.6948 - root_mean_squared_error: 47.3301 - val_loss: 1105.2253 - val_root_mean_squared_error: 33.2449
# Epoch 76/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1581.0004 - root_mean_squared_error: 39.5074 - val_loss: 1100.9249 - val_root_mean_squared_error: 33.1802
# Epoch 77/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1877.6276 - root_mean_squared_error: 43.2663 - val_loss: 1105.8174 - val_root_mean_squared_error: 33.2538
# Epoch 78/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1556.4697 - root_mean_squared_error: 39.4064 - val_loss: 1081.5349 - val_root_mean_squared_error: 32.8867
# Epoch 79/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1636.2758 - root_mean_squared_error: 39.9894 - val_loss: 1087.9037 - val_root_mean_squared_error: 32.9834
# Epoch 80/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1615.8971 - root_mean_squared_error: 40.0111 - val_loss: 1068.4155 - val_root_mean_squared_error: 32.6866
# Epoch 81/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1602.2461 - root_mean_squared_error: 39.7972 - val_loss: 1058.2567 - val_root_mean_squared_error: 32.5309
# Epoch 82/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1592.5651 - root_mean_squared_error: 39.7586 - val_loss: 1052.8293 - val_root_mean_squared_error: 32.4473
# Epoch 83/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1719.5302 - root_mean_squared_error: 41.2954 - val_loss: 1067.8815 - val_root_mean_squared_error: 32.6785
# Epoch 84/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1841.6057 - root_mean_squared_error: 42.7548 - val_loss: 1042.6296 - val_root_mean_squared_error: 32.2898
# Epoch 85/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1928.8739 - root_mean_squared_error: 43.7914 - val_loss: 1050.1062 - val_root_mean_squared_error: 32.4053
# Epoch 86/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1642.1978 - root_mean_squared_error: 40.3351 - val_loss: 1039.5328 - val_root_mean_squared_error: 32.2418
# Epoch 87/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1604.6486 - root_mean_squared_error: 39.9257 - val_loss: 1033.3796 - val_root_mean_squared_error: 32.1462
# Epoch 88/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1541.6370 - root_mean_squared_error: 39.0200 - val_loss: 1046.0229 - val_root_mean_squared_error: 32.3423
# Epoch 89/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1632.9705 - root_mean_squared_error: 40.2832 - val_loss: 1080.0524 - val_root_mean_squared_error: 32.8642
# Epoch 90/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1946.6091 - root_mean_squared_error: 43.8471 - val_loss: 1048.5465 - val_root_mean_squared_error: 32.3813
# Epoch 91/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2212.8271 - root_mean_squared_error: 46.0472 - val_loss: 1034.5219 - val_root_mean_squared_error: 32.1640
# Epoch 92/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1382.1588 - root_mean_squared_error: 36.7776 - val_loss: 1035.2906 - val_root_mean_squared_error: 32.1759
# Epoch 93/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1675.1062 - root_mean_squared_error: 40.6503 - val_loss: 1022.6848 - val_root_mean_squared_error: 31.9794
# Epoch 94/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2677.5632 - root_mean_squared_error: 49.4510 - val_loss: 1040.1537 - val_root_mean_squared_error: 32.2514
# Epoch 95/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1987.8616 - root_mean_squared_error: 44.4540 - val_loss: 1016.4183 - val_root_mean_squared_error: 31.8813
# Epoch 96/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1424.3917 - root_mean_squared_error: 37.5998 - val_loss: 1015.4340 - val_root_mean_squared_error: 31.8659
# Epoch 97/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1587.5773 - root_mean_squared_error: 39.6525 - val_loss: 1037.0765 - val_root_mean_squared_error: 32.2037
# Epoch 98/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1564.9512 - root_mean_squared_error: 39.4844 - val_loss: 1066.3408 - val_root_mean_squared_error: 32.6549
# Epoch 99/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1595.9543 - root_mean_squared_error: 39.9060 - val_loss: 1023.8194 - val_root_mean_squared_error: 31.9972
# Epoch 100/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1826.1562 - root_mean_squared_error: 42.6226 - val_loss: 1030.4558 - val_root_mean_squared_error: 32.1007

# %%
from tensorflow.keras.models import load_model
model1 = load_model('/kaggle/working/model1.keras')

# %%
# Evaluate the model on the train data
train_result = model1.predict(X_train1)

# Calculate metrics
mse = mean_squared_error(y_train1, train_result)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_train1, train_result)
r2 = r2_score(y_train1, train_result)

# Print the results
print("Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (Accuracy): {r2:.4f}")
# Out:
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Evaluation Metrics:
# Mean Absolute Error (MAE): 20.1869
# Mean Squared Error (MSE): 1702.4313
# Root Mean Squared Error (RMSE): 41.2605
# R-squared (Accuracy): 0.6705

# %%
# Evaluate the model on the validation data
val_result = model1.predict(X_val1)

# Calculate metrics
mse = mean_squared_error(y_val1, val_result)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_val1, val_result)
r2 = r2_score(y_val1, val_result)

# Print the results
print("Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (Accuracy): {r2:.4f}")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Evaluation Metrics:
# Mean Absolute Error (MAE): 20.5018
# Mean Squared Error (MSE): 1015.4341
# Root Mean Squared Error (RMSE): 31.8659
# R-squared (Accuracy): 0.8438

# %%
# Evaluate the model on the test data
test_result = model1.predict(X_test1)

# Calculate metrics
mse = mean_squared_error(y_test1, test_result)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test1, test_result)
r2 = r2_score(y_test1, test_result)

# Print the results
print("Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (Accuracy): {r2:.4f}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Evaluation Metrics:
# Mean Absolute Error (MAE): 21.7377
# Mean Squared Error (MSE): 1160.4476
# Root Mean Squared Error (RMSE): 34.0653
# R-squared (Accuracy): 0.6488

# %%
train_predictions = model1.predict(X_train1).flatten()
train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_train1})
train_results
# Out:
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#       Train Predictions  Actuals
# 0            212.390762    195.0
# 1            190.116882    185.0
# 2            192.092270    208.0
# 3            219.790359    290.0
# 4            292.372894    267.0
# ...                 ...      ...
# 2228         237.471329    197.0
# 2229         194.151016    216.0
# 2230         233.726852    223.0
# 2231         225.072281    269.0
# 2232         281.337982    233.0
#
# [2233 rows x 2 columns]

# %%
plt.plot(train_results['Actuals'][1:50], label='Actual')
plt.plot(train_results['Train Predictions'][1:50], label='Predicted')
plt.legend()
plt.show()

# %%
val_predictions = model1.predict(X_val1).flatten()
val_results = pd.DataFrame(data={'Train Predictions':val_predictions, 'Actuals':y_val1})
val_results
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#      Train Predictions  Actuals
# 0           216.291824    183.0
# 1           188.412781    206.0
# 2           222.555283    189.0
# 3           189.302704    181.0
# 4           193.530319    189.0
# ..                 ...      ...
# 628         166.729019    193.0
# 629         225.209305    199.0
# 630         193.248520    197.0
# 631         208.516403    197.0
# 632         203.039169    190.0
#
# [633 rows x 2 columns]

# %%
plt.plot(val_results['Actuals'][1:50], label='Actual')
plt.plot(val_results['Train Predictions'][1:50], label='Predicted')
plt.legend()
plt.show()

# %%
test_predictions = model1.predict(X_test1).flatten()
test_results = pd.DataFrame(data={'Train Predictions':test_predictions, 'Actuals':y_test1})
test_results
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#      Train Predictions  Actuals
# 0           211.803192    190.0
# 1           193.597549    177.0
# 2           185.977554    172.0
# 3           178.555389    170.0
# 4           176.356781    197.0
# ..                 ...      ...
# 310         154.991531    134.0
# 311         135.522964    144.0
# 312         147.390289    155.0
# 313         153.142532    155.0
# 314         154.046402    152.0
#
# [315 rows x 2 columns]

# %%
plt.plot(test_results['Train Predictions'][1:50], label='Predicted')
plt.plot(test_results['Actuals'][1:50], label='Actual')
plt.legend()
plt.show()

# %% [markdown]
# # **GRU(aqi_smooth_rolling)**

# %%
model2 = Sequential()
model2.add(InputLayer((6, 1)))
model2.add(GRU(32))
model2.add(Dense(8, 'relu'))
model2.add(Dense(1, 'linear'))
model2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru (GRU)                            │ (None, 32)                  │           3,360 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 8)                   │             264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,633 (14.19 KB)
#  Trainable params: 3,633 (14.19 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp2 = ModelCheckpoint('/kaggle/working/model2.keras', save_best_only=True)
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0005), 
               metrics=[RootMeanSquaredError()])

# %%
model2.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), 
           epochs=100, callbacks=[cp2])
# Out:
# Epoch 1/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 32423.7910 - root_mean_squared_error: 180.0270 - val_loss: 34342.5703 - val_root_mean_squared_error: 185.3175
# Epoch 2/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30095.5430 - root_mean_squared_error: 173.4692 - val_loss: 33485.7109 - val_root_mean_squared_error: 182.9910
# Epoch 3/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30186.3730 - root_mean_squared_error: 173.6700 - val_loss: 31096.8027 - val_root_mean_squared_error: 176.3428
# Epoch 4/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 26391.1289 - root_mean_squared_error: 162.4420 - val_loss: 29130.0957 - val_root_mean_squared_error: 170.6754
# Epoch 5/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 26227.7852 - root_mean_squared_error: 161.9193 - val_loss: 27298.2441 - val_root_mean_squared_error: 165.2218
# Epoch 6/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 24590.4824 - root_mean_squared_error: 156.7697 - val_loss: 25247.0449 - val_root_mean_squared_error: 158.8932
# Epoch 7/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21227.6445 - root_mean_squared_error: 145.6756 - val_loss: 23279.5137 - val_root_mean_squared_error: 152.5762
# Epoch 8/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20988.4863 - root_mean_squared_error: 144.5059 - val_loss: 21040.4297 - val_root_mean_squared_error: 145.0532
# Epoch 9/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17056.8301 - root_mean_squared_error: 130.5446 - val_loss: 18712.6543 - val_root_mean_squared_error: 136.7942
# Epoch 10/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16156.4785 - root_mean_squared_error: 127.0465 - val_loss: 16764.5391 - val_root_mean_squared_error: 129.4780
# Epoch 11/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13433.4199 - root_mean_squared_error: 115.8604 - val_loss: 14979.2793 - val_root_mean_squared_error: 122.3899
# Epoch 12/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12378.1035 - root_mean_squared_error: 111.1574 - val_loss: 13373.3779 - val_root_mean_squared_error: 115.6433
# Epoch 13/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10442.3428 - root_mean_squared_error: 102.1688 - val_loss: 11970.6211 - val_root_mean_squared_error: 109.4103
# Epoch 14/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9837.2607 - root_mean_squared_error: 99.0011 - val_loss: 10729.3672 - val_root_mean_squared_error: 103.5827
# Epoch 15/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8746.4854 - root_mean_squared_error: 93.4833 - val_loss: 9596.0996 - val_root_mean_squared_error: 97.9597
# Epoch 16/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7596.0522 - root_mean_squared_error: 86.7553 - val_loss: 8519.8867 - val_root_mean_squared_error: 92.3032
# Epoch 17/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7099.3867 - root_mean_squared_error: 84.1626 - val_loss: 7569.5552 - val_root_mean_squared_error: 87.0032
# Epoch 18/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5181.2534 - root_mean_squared_error: 71.8469 - val_loss: 6781.9219 - val_root_mean_squared_error: 82.3524
# Epoch 19/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5115.5815 - root_mean_squared_error: 71.4293 - val_loss: 6128.4644 - val_root_mean_squared_error: 78.2845
# Epoch 20/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4288.0698 - root_mean_squared_error: 65.2661 - val_loss: 5596.9927 - val_root_mean_squared_error: 74.8130
# Epoch 21/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4236.6631 - root_mean_squared_error: 64.9380 - val_loss: 5110.4043 - val_root_mean_squared_error: 71.4871
# Epoch 22/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3972.8308 - root_mean_squared_error: 62.8263 - val_loss: 4702.0952 - val_root_mean_squared_error: 68.5718
# Epoch 23/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4029.3101 - root_mean_squared_error: 63.2102 - val_loss: 4327.0874 - val_root_mean_squared_error: 65.7806
# Epoch 24/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3181.1064 - root_mean_squared_error: 56.2717 - val_loss: 3961.6931 - val_root_mean_squared_error: 62.9420
# Epoch 25/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3552.3772 - root_mean_squared_error: 59.1746 - val_loss: 3675.9839 - val_root_mean_squared_error: 60.6299
# Epoch 26/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3211.1711 - root_mean_squared_error: 56.3340 - val_loss: 3463.5107 - val_root_mean_squared_error: 58.8516
# Epoch 27/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3489.0681 - root_mean_squared_error: 58.8938 - val_loss: 3220.6697 - val_root_mean_squared_error: 56.7509
# Epoch 28/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2600.8169 - root_mean_squared_error: 50.7338 - val_loss: 3011.6724 - val_root_mean_squared_error: 54.8787
# Epoch 29/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3403.6838 - root_mean_squared_error: 57.7034 - val_loss: 2850.7231 - val_root_mean_squared_error: 53.3922
# Epoch 30/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3081.4888 - root_mean_squared_error: 55.0286 - val_loss: 2643.6296 - val_root_mean_squared_error: 51.4162
# Epoch 31/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3230.9436 - root_mean_squared_error: 56.0367 - val_loss: 2457.8818 - val_root_mean_squared_error: 49.5770
# Epoch 32/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3484.0913 - root_mean_squared_error: 58.3334 - val_loss: 2330.1187 - val_root_mean_squared_error: 48.2713
# Epoch 33/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2295.8015 - root_mean_squared_error: 47.7100 - val_loss: 2203.4780 - val_root_mean_squared_error: 46.9412
# Epoch 34/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2557.5222 - root_mean_squared_error: 50.4655 - val_loss: 2052.1021 - val_root_mean_squared_error: 45.3001
# Epoch 35/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2682.7754 - root_mean_squared_error: 51.0993 - val_loss: 1945.1526 - val_root_mean_squared_error: 44.1039
# Epoch 36/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1991.8566 - root_mean_squared_error: 44.4138 - val_loss: 1851.7561 - val_root_mean_squared_error: 43.0320
# Epoch 37/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2556.5237 - root_mean_squared_error: 50.3595 - val_loss: 1773.0741 - val_root_mean_squared_error: 42.1079
# Epoch 38/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2853.1978 - root_mean_squared_error: 52.9835 - val_loss: 1676.4319 - val_root_mean_squared_error: 40.9443
# Epoch 39/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1495.7081 - root_mean_squared_error: 38.3648 - val_loss: 1611.0927 - val_root_mean_squared_error: 40.1384
# Epoch 40/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1596.6368 - root_mean_squared_error: 39.5272 - val_loss: 1532.5629 - val_root_mean_squared_error: 39.1480
# Epoch 41/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1874.0675 - root_mean_squared_error: 43.1345 - val_loss: 1473.5774 - val_root_mean_squared_error: 38.3872
# Epoch 42/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1947.6255 - root_mean_squared_error: 44.0846 - val_loss: 1464.5072 - val_root_mean_squared_error: 38.2689
# Epoch 43/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1888.9556 - root_mean_squared_error: 43.0606 - val_loss: 1420.5131 - val_root_mean_squared_error: 37.6897
# Epoch 44/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2159.2991 - root_mean_squared_error: 46.2230 - val_loss: 1361.3149 - val_root_mean_squared_error: 36.8960
# Epoch 45/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2092.3972 - root_mean_squared_error: 45.4632 - val_loss: 1308.9435 - val_root_mean_squared_error: 36.1793
# Epoch 46/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1639.1129 - root_mean_squared_error: 40.2716 - val_loss: 1274.6769 - val_root_mean_squared_error: 35.7026
# Epoch 47/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2769.3293 - root_mean_squared_error: 51.9916 - val_loss: 1253.2828 - val_root_mean_squared_error: 35.4017
# Epoch 48/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2053.7205 - root_mean_squared_error: 45.1757 - val_loss: 1192.3649 - val_root_mean_squared_error: 34.5306
# Epoch 49/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1577.7410 - root_mean_squared_error: 39.6499 - val_loss: 1226.9340 - val_root_mean_squared_error: 35.0276
# Epoch 50/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1678.8070 - root_mean_squared_error: 40.8890 - val_loss: 1178.8082 - val_root_mean_squared_error: 34.3338
# Epoch 51/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1865.4152 - root_mean_squared_error: 43.1353 - val_loss: 1147.2810 - val_root_mean_squared_error: 33.8715
# Epoch 52/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1651.8771 - root_mean_squared_error: 40.4858 - val_loss: 1119.4076 - val_root_mean_squared_error: 33.4576
# Epoch 53/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1867.0155 - root_mean_squared_error: 42.9196 - val_loss: 1149.9312 - val_root_mean_squared_error: 33.9106
# Epoch 54/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1625.2454 - root_mean_squared_error: 40.0267 - val_loss: 1106.6675 - val_root_mean_squared_error: 33.2666
# Epoch 55/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1250.2842 - root_mean_squared_error: 35.0738 - val_loss: 1117.9557 - val_root_mean_squared_error: 33.4358
# Epoch 56/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1744.3453 - root_mean_squared_error: 41.6592 - val_loss: 1104.9099 - val_root_mean_squared_error: 33.2402
# Epoch 57/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1959.4098 - root_mean_squared_error: 43.9887 - val_loss: 1234.8690 - val_root_mean_squared_error: 35.1407
# Epoch 58/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1715.6820 - root_mean_squared_error: 41.0108 - val_loss: 1100.0488 - val_root_mean_squared_error: 33.1670
# Epoch 59/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1806.7225 - root_mean_squared_error: 42.4180 - val_loss: 1035.9326 - val_root_mean_squared_error: 32.1859
# Epoch 60/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2040.8069 - root_mean_squared_error: 44.9898 - val_loss: 1087.7921 - val_root_mean_squared_error: 32.9817
# Epoch 61/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2417.6196 - root_mean_squared_error: 48.2934 - val_loss: 1072.8987 - val_root_mean_squared_error: 32.7551
# Epoch 62/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2256.2144 - root_mean_squared_error: 47.0912 - val_loss: 1006.0545 - val_root_mean_squared_error: 31.7184
# Epoch 63/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1565.0056 - root_mean_squared_error: 39.4155 - val_loss: 1037.4574 - val_root_mean_squared_error: 32.2096
# Epoch 64/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1827.5524 - root_mean_squared_error: 42.6934 - val_loss: 1085.9061 - val_root_mean_squared_error: 32.9531
# Epoch 65/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1494.7799 - root_mean_squared_error: 38.5166 - val_loss: 999.4573 - val_root_mean_squared_error: 31.6142
# Epoch 66/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1689.5853 - root_mean_squared_error: 40.7103 - val_loss: 1007.0789 - val_root_mean_squared_error: 31.7345
# Epoch 67/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2397.6826 - root_mean_squared_error: 48.1315 - val_loss: 1190.7090 - val_root_mean_squared_error: 34.5067
# Epoch 68/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1558.4122 - root_mean_squared_error: 39.3067 - val_loss: 1107.6853 - val_root_mean_squared_error: 33.2819
# Epoch 69/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1723.9720 - root_mean_squared_error: 41.3601 - val_loss: 1087.8168 - val_root_mean_squared_error: 32.9821
# Epoch 70/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1737.0193 - root_mean_squared_error: 41.3723 - val_loss: 1128.8074 - val_root_mean_squared_error: 33.5977
# Epoch 71/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1635.9198 - root_mean_squared_error: 40.2938 - val_loss: 1097.9667 - val_root_mean_squared_error: 33.1356
# Epoch 72/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1849.4309 - root_mean_squared_error: 42.9304 - val_loss: 1038.2701 - val_root_mean_squared_error: 32.2222
# Epoch 73/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1549.4017 - root_mean_squared_error: 38.9955 - val_loss: 1143.6072 - val_root_mean_squared_error: 33.8173
# Epoch 74/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1626.8989 - root_mean_squared_error: 39.9821 - val_loss: 1053.2410 - val_root_mean_squared_error: 32.4537
# Epoch 75/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1741.5972 - root_mean_squared_error: 41.3402 - val_loss: 1025.2797 - val_root_mean_squared_error: 32.0200
# Epoch 76/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1552.5679 - root_mean_squared_error: 39.3400 - val_loss: 1051.6294 - val_root_mean_squared_error: 32.4288
# Epoch 77/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1615.8539 - root_mean_squared_error: 39.8730 - val_loss: 1255.9351 - val_root_mean_squared_error: 35.4392
# Epoch 78/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1860.0485 - root_mean_squared_error: 42.9010 - val_loss: 1186.1493 - val_root_mean_squared_error: 34.4405
# Epoch 79/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1185.0701 - root_mean_squared_error: 34.1879 - val_loss: 1039.8390 - val_root_mean_squared_error: 32.2465
# Epoch 80/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2067.3826 - root_mean_squared_error: 45.2442 - val_loss: 1010.6312 - val_root_mean_squared_error: 31.7904
# Epoch 81/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1434.7502 - root_mean_squared_error: 37.7691 - val_loss: 1099.1827 - val_root_mean_squared_error: 33.1539
# Epoch 82/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1472.9207 - root_mean_squared_error: 38.2958 - val_loss: 1007.3754 - val_root_mean_squared_error: 31.7392
# Epoch 83/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1474.6499 - root_mean_squared_error: 38.1042 - val_loss: 1051.2496 - val_root_mean_squared_error: 32.4230
# Epoch 84/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1662.4943 - root_mean_squared_error: 40.6739 - val_loss: 1014.2262 - val_root_mean_squared_error: 31.8469
# Epoch 85/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1468.5117 - root_mean_squared_error: 38.0146 - val_loss: 1073.1141 - val_root_mean_squared_error: 32.7584
# Epoch 86/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2205.9800 - root_mean_squared_error: 46.3470 - val_loss: 1168.7960 - val_root_mean_squared_error: 34.1877
# Epoch 87/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1938.2375 - root_mean_squared_error: 43.5328 - val_loss: 1115.5319 - val_root_mean_squared_error: 33.3996
# Epoch 88/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1926.7098 - root_mean_squared_error: 43.5014 - val_loss: 1239.7600 - val_root_mean_squared_error: 35.2102
# Epoch 89/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1984.8860 - root_mean_squared_error: 44.1148 - val_loss: 1054.9302 - val_root_mean_squared_error: 32.4797
# Epoch 90/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2134.3066 - root_mean_squared_error: 45.3621 - val_loss: 1098.6628 - val_root_mean_squared_error: 33.1461
# Epoch 91/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1654.7040 - root_mean_squared_error: 40.5389 - val_loss: 1055.4910 - val_root_mean_squared_error: 32.4883
# Epoch 92/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1811.1133 - root_mean_squared_error: 42.4294 - val_loss: 1088.0842 - val_root_mean_squared_error: 32.9861
# Epoch 93/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1529.7258 - root_mean_squared_error: 38.9195 - val_loss: 1069.6835 - val_root_mean_squared_error: 32.7060
# Epoch 94/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1611.6523 - root_mean_squared_error: 39.8952 - val_loss: 1063.1553 - val_root_mean_squared_error: 32.6061
# Epoch 95/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1693.8203 - root_mean_squared_error: 41.0037 - val_loss: 1168.9092 - val_root_mean_squared_error: 34.1893
# Epoch 96/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1388.8572 - root_mean_squared_error: 37.1452 - val_loss: 1021.7283 - val_root_mean_squared_error: 31.9645
# Epoch 97/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1623.2909 - root_mean_squared_error: 40.2498 - val_loss: 1087.8529 - val_root_mean_squared_error: 32.9826
# Epoch 98/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1802.8381 - root_mean_squared_error: 42.3200 - val_loss: 1147.0315 - val_root_mean_squared_error: 33.8679
# Epoch 99/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1927.2720 - root_mean_squared_error: 43.4128 - val_loss: 1126.1743 - val_root_mean_squared_error: 33.5585
# Epoch 100/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1475.4050 - root_mean_squared_error: 38.2326 - val_loss: 1039.0948 - val_root_mean_squared_error: 32.2350

# %%
from tensorflow.keras.models import load_model
model2 = load_model('/kaggle/working/model2.keras')

# %%
# Evaluate the model on the train data
train_result = model2.predict(X_train1)

# Calculate metrics
mse = mean_squared_error(y_train1, train_result)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_train1, train_result)
r2 = r2_score(y_train1, train_result)

# Print the results
print("Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (Accuracy): {r2:.4f}")
# Out:
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Evaluation Metrics:
# Mean Absolute Error (MAE): 19.8054
# Mean Squared Error (MSE): 1726.7133
# Root Mean Squared Error (RMSE): 41.5537
# R-squared (Accuracy): 0.6658

# %%
# Evaluate the model on the validation data
val_result = model2.predict(X_val1)

# Calculate metrics
mse = mean_squared_error(y_val1, val_result)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_val1, val_result)
r2 = r2_score(y_val1, val_result)

# Print the results
print("Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (Accuracy): {r2:.4f}")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Evaluation Metrics:
# Mean Absolute Error (MAE): 19.8878
# Mean Squared Error (MSE): 999.4573
# Root Mean Squared Error (RMSE): 31.6142
# R-squared (Accuracy): 0.8462

# %%
# Evaluate the model on the test data
test_result = model2.predict(X_test1)

# Calculate metrics
mse = mean_squared_error(y_test1, test_result)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test1, test_result)
r2 = r2_score(y_test1, test_result)

# Print the results
print("Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (Accuracy): {r2:.4f}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Evaluation Metrics:
# Mean Absolute Error (MAE): 21.3935
# Mean Squared Error (MSE): 1121.5072
# Root Mean Squared Error (RMSE): 33.4889
# R-squared (Accuracy): 0.6606

# %%
train_predictions = model2.predict(X_train1).flatten()
train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_train1})
train_results
# Out:
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#       Train Predictions  Actuals
# 0            203.120956    195.0
# 1            196.666107    185.0
# 2            186.759552    208.0
# 3            214.299774    290.0
# 4            288.484436    267.0
# ...                 ...      ...
# 2228         229.429718    197.0
# 2229         190.268585    216.0
# 2230         232.620667    223.0
# 2231         222.008545    269.0
# 2232         277.631531    233.0
#
# [2233 rows x 2 columns]

# %%
plt.plot(train_results['Actuals'][1:50], label='Actual')
plt.plot(train_results['Train Predictions'][1:50], label='Predicted')
plt.legend()
plt.show()

# %%
val_predictions = model2.predict(X_val1).flatten()
val_results = pd.DataFrame(data={'Train Predictions':val_predictions, 'Actuals':y_val1})
val_results
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#      Train Predictions  Actuals
# 0           211.864853    183.0
# 1           183.214493    206.0
# 2           217.047958    189.0
# 3           184.525208    181.0
# 4           187.463745    189.0
# ..                 ...      ...
# 628         177.840240    193.0
# 629         214.144058    199.0
# 630         196.743454    197.0
# 631         204.850555    197.0
# 632         198.923294    190.0
#
# [633 rows x 2 columns]

# %%
plt.plot(val_results['Actuals'][1:50], label='Actual')
plt.plot(val_results['Train Predictions'][1:50], label='Predicted')
plt.legend()
plt.show()

# %%
test_predictions = model2.predict(X_test1).flatten()
test_results = pd.DataFrame(data={'Train Predictions':test_predictions, 'Actuals':y_test1})
test_results
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#      Train Predictions  Actuals
# 0           205.702820    190.0
# 1           187.689301    177.0
# 2           180.521133    172.0
# 3           173.526260    170.0
# 4           170.528061    197.0
# ..                 ...      ...
# 310         153.723297    134.0
# 311         137.251297    144.0
# 312         145.143250    155.0
# 313         152.433563    155.0
# 314         153.078430    152.0
#
# [315 rows x 2 columns]

# %%
plt.plot(test_results['Train Predictions'][1:50], label='Predicted')
plt.plot(test_results['Actuals'][1:50], label='Actual')
plt.legend()
plt.show()

# %% [markdown]
# # RNN(aqi_smooth_rolling)

# %%
model3 = Sequential()
model3.add(InputLayer((6, 1)))
model3.add(SimpleRNN(32))
model3.add(Dense(8, 'relu'))
model3.add(Dense(1, 'linear'))
model3.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)               │ (None, 32)                  │           1,088 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 8)                   │             264 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,361 (5.32 KB)
#  Trainable params: 1,361 (5.32 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp3 = ModelCheckpoint('/kaggle/working/model3.keras', save_best_only=True)
model3.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0005), 
               metrics=[RootMeanSquaredError()])

# %%
model3.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), 
           epochs=100, callbacks=[cp3])
# Out:
# Epoch 1/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 31988.1641 - root_mean_squared_error: 178.8167 - val_loss: 34229.8516 - val_root_mean_squared_error: 185.0131
# Epoch 2/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 30610.7285 - root_mean_squared_error: 174.9052 - val_loss: 33300.1328 - val_root_mean_squared_error: 182.4832
# Epoch 3/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29722.4980 - root_mean_squared_error: 172.3878 - val_loss: 32451.3301 - val_root_mean_squared_error: 180.1425
# Epoch 4/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 29686.1387 - root_mean_squared_error: 172.2679 - val_loss: 31618.6504 - val_root_mean_squared_error: 177.8163
# Epoch 5/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28575.5859 - root_mean_squared_error: 168.9922 - val_loss: 30709.6660 - val_root_mean_squared_error: 175.2417
# Epoch 6/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 28440.8164 - root_mean_squared_error: 168.5517 - val_loss: 29725.6738 - val_root_mean_squared_error: 172.4113
# Epoch 7/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 25635.8730 - root_mean_squared_error: 160.0567 - val_loss: 28674.9707 - val_root_mean_squared_error: 169.3369
# Epoch 8/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 25616.8496 - root_mean_squared_error: 160.0364 - val_loss: 27571.4277 - val_root_mean_squared_error: 166.0465
# Epoch 9/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 25655.9316 - root_mean_squared_error: 160.0329 - val_loss: 26423.2031 - val_root_mean_squared_error: 162.5522
# Epoch 10/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22975.5430 - root_mean_squared_error: 151.5165 - val_loss: 25246.0156 - val_root_mean_squared_error: 158.8900
# Epoch 11/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 21921.8906 - root_mean_squared_error: 148.0530 - val_loss: 24042.4004 - val_root_mean_squared_error: 155.0561
# Epoch 12/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 21445.9707 - root_mean_squared_error: 146.3728 - val_loss: 22826.6875 - val_root_mean_squared_error: 151.0850
# Epoch 13/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19186.0527 - root_mean_squared_error: 138.4999 - val_loss: 21613.2227 - val_root_mean_squared_error: 147.0144
# Epoch 14/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 18803.0918 - root_mean_squared_error: 137.0673 - val_loss: 20403.4961 - val_root_mean_squared_error: 142.8408
# Epoch 15/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 17606.8301 - root_mean_squared_error: 132.6572 - val_loss: 19218.2930 - val_root_mean_squared_error: 138.6301
# Epoch 16/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16954.2969 - root_mean_squared_error: 130.1629 - val_loss: 18062.4141 - val_root_mean_squared_error: 134.3965
# Epoch 17/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15791.1543 - root_mean_squared_error: 125.6194 - val_loss: 16945.8047 - val_root_mean_squared_error: 130.1761
# Epoch 18/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 14075.4844 - root_mean_squared_error: 118.5443 - val_loss: 15876.1885 - val_root_mean_squared_error: 126.0007
# Epoch 19/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13172.1523 - root_mean_squared_error: 114.7318 - val_loss: 14861.4443 - val_root_mean_squared_error: 121.9075
# Epoch 20/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12089.8193 - root_mean_squared_error: 109.8875 - val_loss: 13897.9844 - val_root_mean_squared_error: 117.8897
# Epoch 21/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12057.5000 - root_mean_squared_error: 109.7465 - val_loss: 12999.9355 - val_root_mean_squared_error: 114.0173
# Epoch 22/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9993.9258 - root_mean_squared_error: 99.8655 - val_loss: 12168.1992 - val_root_mean_squared_error: 110.3096
# Epoch 23/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9309.0586 - root_mean_squared_error: 96.4432 - val_loss: 11387.8232 - val_root_mean_squared_error: 106.7137
# Epoch 24/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9835.4932 - root_mean_squared_error: 99.0880 - val_loss: 10614.9414 - val_root_mean_squared_error: 103.0288
# Epoch 25/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8365.7871 - root_mean_squared_error: 91.3941 - val_loss: 9924.4746 - val_root_mean_squared_error: 99.6217
# Epoch 26/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7940.0957 - root_mean_squared_error: 89.0403 - val_loss: 9285.3984 - val_root_mean_squared_error: 96.3608
# Epoch 27/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6708.1392 - root_mean_squared_error: 81.8262 - val_loss: 8680.5361 - val_root_mean_squared_error: 93.1694
# Epoch 28/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7124.4512 - root_mean_squared_error: 84.3253 - val_loss: 8123.0024 - val_root_mean_squared_error: 90.1277
# Epoch 29/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6743.8135 - root_mean_squared_error: 82.0010 - val_loss: 7611.2607 - val_root_mean_squared_error: 87.2425
# Epoch 30/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5809.6768 - root_mean_squared_error: 76.1246 - val_loss: 7138.9390 - val_root_mean_squared_error: 84.4922
# Epoch 31/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6111.3921 - root_mean_squared_error: 78.0210 - val_loss: 6713.0269 - val_root_mean_squared_error: 81.9331
# Epoch 32/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5607.6777 - root_mean_squared_error: 74.5779 - val_loss: 6318.7524 - val_root_mean_squared_error: 79.4906
# Epoch 33/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4250.2451 - root_mean_squared_error: 65.1405 - val_loss: 5985.6792 - val_root_mean_squared_error: 77.3672
# Epoch 34/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4126.2871 - root_mean_squared_error: 64.0570 - val_loss: 5639.1694 - val_root_mean_squared_error: 75.0944
# Epoch 35/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3837.2966 - root_mean_squared_error: 61.7773 - val_loss: 5347.2842 - val_root_mean_squared_error: 73.1251
# Epoch 36/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4337.2612 - root_mean_squared_error: 65.6977 - val_loss: 5068.7173 - val_root_mean_squared_error: 71.1949
# Epoch 37/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3930.1460 - root_mean_squared_error: 62.4572 - val_loss: 4817.9546 - val_root_mean_squared_error: 69.4115
# Epoch 38/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5093.7046 - root_mean_squared_error: 70.7054 - val_loss: 4600.5093 - val_root_mean_squared_error: 67.8271
# Epoch 39/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3956.1636 - root_mean_squared_error: 62.7597 - val_loss: 4363.0771 - val_root_mean_squared_error: 66.0536
# Epoch 40/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3729.6157 - root_mean_squared_error: 60.8661 - val_loss: 4176.1309 - val_root_mean_squared_error: 64.6230
# Epoch 41/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2898.6873 - root_mean_squared_error: 53.5853 - val_loss: 4022.5098 - val_root_mean_squared_error: 63.4233
# Epoch 42/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3138.5535 - root_mean_squared_error: 55.7952 - val_loss: 3822.9036 - val_root_mean_squared_error: 61.8296
# Epoch 43/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3088.9385 - root_mean_squared_error: 55.2995 - val_loss: 3654.2556 - val_root_mean_squared_error: 60.4504
# Epoch 44/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2958.5149 - root_mean_squared_error: 53.9892 - val_loss: 3508.9802 - val_root_mean_squared_error: 59.2366
# Epoch 45/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2937.7292 - root_mean_squared_error: 53.8879 - val_loss: 3399.5742 - val_root_mean_squared_error: 58.3059
# Epoch 46/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2986.4219 - root_mean_squared_error: 54.4288 - val_loss: 3230.1714 - val_root_mean_squared_error: 56.8346
# Epoch 47/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2416.7463 - root_mean_squared_error: 48.9185 - val_loss: 3126.0193 - val_root_mean_squared_error: 55.9108
# Epoch 48/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3575.4775 - root_mean_squared_error: 59.2531 - val_loss: 2970.6770 - val_root_mean_squared_error: 54.5039
# Epoch 49/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2515.1377 - root_mean_squared_error: 49.9835 - val_loss: 2877.6648 - val_root_mean_squared_error: 53.6439
# Epoch 50/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2684.7041 - root_mean_squared_error: 51.5289 - val_loss: 2744.1924 - val_root_mean_squared_error: 52.3850
# Epoch 51/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2958.8569 - root_mean_squared_error: 54.2233 - val_loss: 2655.6389 - val_root_mean_squared_error: 51.5329
# Epoch 52/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2462.2366 - root_mean_squared_error: 49.3655 - val_loss: 2549.3120 - val_root_mean_squared_error: 50.4907
# Epoch 53/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3063.4824 - root_mean_squared_error: 54.7906 - val_loss: 2455.4182 - val_root_mean_squared_error: 49.5522
# Epoch 54/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2426.1389 - root_mean_squared_error: 49.0732 - val_loss: 2364.9631 - val_root_mean_squared_error: 48.6309
# Epoch 55/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2318.3218 - root_mean_squared_error: 48.1016 - val_loss: 2260.6824 - val_root_mean_squared_error: 47.5466
# Epoch 56/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2385.5354 - root_mean_squared_error: 48.6192 - val_loss: 2178.9236 - val_root_mean_squared_error: 46.6789
# Epoch 57/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2235.0112 - root_mean_squared_error: 47.1103 - val_loss: 2100.3608 - val_root_mean_squared_error: 45.8297
# Epoch 58/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3309.9805 - root_mean_squared_error: 55.8373 - val_loss: 2021.6511 - val_root_mean_squared_error: 44.9628
# Epoch 59/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2278.5674 - root_mean_squared_error: 47.3230 - val_loss: 1943.1921 - val_root_mean_squared_error: 44.0817
# Epoch 60/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2795.1650 - root_mean_squared_error: 52.0066 - val_loss: 1879.4620 - val_root_mean_squared_error: 43.3528
# Epoch 61/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2726.5107 - root_mean_squared_error: 51.5034 - val_loss: 1819.9220 - val_root_mean_squared_error: 42.6605
# Epoch 62/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2145.2412 - root_mean_squared_error: 46.0364 - val_loss: 1752.3251 - val_root_mean_squared_error: 41.8608
# Epoch 63/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1829.1776 - root_mean_squared_error: 42.4318 - val_loss: 1722.1157 - val_root_mean_squared_error: 41.4984
# Epoch 64/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2348.3635 - root_mean_squared_error: 47.5880 - val_loss: 1653.8798 - val_root_mean_squared_error: 40.6679
# Epoch 65/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1780.5919 - root_mean_squared_error: 41.9760 - val_loss: 1604.5984 - val_root_mean_squared_error: 40.0574
# Epoch 66/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2351.5925 - root_mean_squared_error: 48.1599 - val_loss: 1552.4415 - val_root_mean_squared_error: 39.4010
# Epoch 67/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1677.9062 - root_mean_squared_error: 40.5618 - val_loss: 1515.5854 - val_root_mean_squared_error: 38.9305
# Epoch 68/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2536.6616 - root_mean_squared_error: 50.0671 - val_loss: 1481.4048 - val_root_mean_squared_error: 38.4890
# Epoch 69/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1707.8436 - root_mean_squared_error: 40.9523 - val_loss: 1444.2192 - val_root_mean_squared_error: 38.0029
# Epoch 70/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1915.6605 - root_mean_squared_error: 43.6610 - val_loss: 1404.8739 - val_root_mean_squared_error: 37.4816
# Epoch 71/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1734.4602 - root_mean_squared_error: 41.5265 - val_loss: 1358.3291 - val_root_mean_squared_error: 36.8555
# Epoch 72/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2112.0842 - root_mean_squared_error: 45.8285 - val_loss: 1346.8562 - val_root_mean_squared_error: 36.6995
# Epoch 73/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1772.5168 - root_mean_squared_error: 42.0332 - val_loss: 1353.1547 - val_root_mean_squared_error: 36.7853
# Epoch 74/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1446.1790 - root_mean_squared_error: 37.6931 - val_loss: 1291.3730 - val_root_mean_squared_error: 35.9357
# Epoch 75/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1822.6744 - root_mean_squared_error: 42.4741 - val_loss: 1249.1710 - val_root_mean_squared_error: 35.3436
# Epoch 76/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2357.7563 - root_mean_squared_error: 47.8111 - val_loss: 1262.0482 - val_root_mean_squared_error: 35.5253
# Epoch 77/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1856.2571 - root_mean_squared_error: 42.8766 - val_loss: 1203.1774 - val_root_mean_squared_error: 34.6868
# Epoch 78/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1959.9468 - root_mean_squared_error: 44.1809 - val_loss: 1193.1633 - val_root_mean_squared_error: 34.5422
# Epoch 79/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2047.0955 - root_mean_squared_error: 44.7253 - val_loss: 1209.8468 - val_root_mean_squared_error: 34.7829
# Epoch 80/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1813.9650 - root_mean_squared_error: 42.3116 - val_loss: 1196.7520 - val_root_mean_squared_error: 34.5941
# Epoch 81/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2143.4087 - root_mean_squared_error: 46.0535 - val_loss: 1167.3292 - val_root_mean_squared_error: 34.1662
# Epoch 82/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1904.3695 - root_mean_squared_error: 43.5895 - val_loss: 1147.4501 - val_root_mean_squared_error: 33.8740
# Epoch 83/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1661.2543 - root_mean_squared_error: 40.5339 - val_loss: 1111.9875 - val_root_mean_squared_error: 33.3465
# Epoch 84/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1596.3184 - root_mean_squared_error: 39.7880 - val_loss: 1141.3293 - val_root_mean_squared_error: 33.7836
# Epoch 85/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1560.2557 - root_mean_squared_error: 39.2141 - val_loss: 1113.2341 - val_root_mean_squared_error: 33.3652
# Epoch 86/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1771.4686 - root_mean_squared_error: 42.0138 - val_loss: 1083.6659 - val_root_mean_squared_error: 32.9191
# Epoch 87/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1561.2444 - root_mean_squared_error: 39.3327 - val_loss: 1092.4376 - val_root_mean_squared_error: 33.0520
# Epoch 88/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2511.6509 - root_mean_squared_error: 48.4065 - val_loss: 1106.5385 - val_root_mean_squared_error: 33.2647
# Epoch 89/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1880.9655 - root_mean_squared_error: 43.2815 - val_loss: 1088.0875 - val_root_mean_squared_error: 32.9862
# Epoch 90/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1671.4141 - root_mean_squared_error: 40.4763 - val_loss: 1072.2032 - val_root_mean_squared_error: 32.7445
# Epoch 91/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1531.8075 - root_mean_squared_error: 39.0406 - val_loss: 1072.7864 - val_root_mean_squared_error: 32.7534
# Epoch 92/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1631.4829 - root_mean_squared_error: 40.2592 - val_loss: 1040.3668 - val_root_mean_squared_error: 32.2547
# Epoch 93/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1803.0140 - root_mean_squared_error: 42.2371 - val_loss: 1039.7290 - val_root_mean_squared_error: 32.2448
# Epoch 94/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1759.8788 - root_mean_squared_error: 41.7205 - val_loss: 1154.1603 - val_root_mean_squared_error: 33.9729
# Epoch 95/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1632.2799 - root_mean_squared_error: 40.2614 - val_loss: 1045.1907 - val_root_mean_squared_error: 32.3294
# Epoch 96/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2066.5195 - root_mean_squared_error: 45.3863 - val_loss: 1152.5282 - val_root_mean_squared_error: 33.9489
# Epoch 97/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1876.9452 - root_mean_squared_error: 43.1715 - val_loss: 1079.2242 - val_root_mean_squared_error: 32.8515
# Epoch 98/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2111.9431 - root_mean_squared_error: 45.6279 - val_loss: 1095.1190 - val_root_mean_squared_error: 33.0926
# Epoch 99/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2195.1292 - root_mean_squared_error: 46.3765 - val_loss: 1112.2523 - val_root_mean_squared_error: 33.3504
# Epoch 100/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2035.7699 - root_mean_squared_error: 44.7114 - val_loss: 1140.3044 - val_root_mean_squared_error: 33.7684

# %%
from tensorflow.keras.models import load_model
model3 = load_model('/kaggle/working/model3.keras')

# %%
# Evaluate the model on the train data
train_result = model3.predict(X_train1)

# Calculate metrics
mse = mean_squared_error(y_train1, train_result)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_train1, train_result)
r2 = r2_score(y_train1, train_result)

# Print the results
print("Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (Accuracy): {r2:.4f}")
# Out:
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Evaluation Metrics:
# Mean Absolute Error (MAE): 20.0359
# Mean Squared Error (MSE): 1775.9227
# Root Mean Squared Error (RMSE): 42.1417
# R-squared (Accuracy): 0.6563

# %%
# Evaluate the model on the validation data
val_result = model3.predict(X_val1)

# Calculate metrics
mse = mean_squared_error(y_val1, val_result)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_val1, val_result)
r2 = r2_score(y_val1, val_result)

# Print the results
print("Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (Accuracy): {r2:.4f}")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Evaluation Metrics:
# Mean Absolute Error (MAE): 20.7113
# Mean Squared Error (MSE): 1039.7290
# Root Mean Squared Error (RMSE): 32.2448
# R-squared (Accuracy): 0.8400

# %%
# Evaluate the model on the test data
test_result = model3.predict(X_test1)

# Calculate metrics
mse = mean_squared_error(y_test1, test_result)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test1, test_result)
r2 = r2_score(y_test1, test_result)

# Print the results
print("Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (Accuracy): {r2:.4f}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Evaluation Metrics:
# Mean Absolute Error (MAE): 21.5161
# Mean Squared Error (MSE): 1124.7748
# Root Mean Squared Error (RMSE): 33.5377
# R-squared (Accuracy): 0.6596

# %%
train_predictions = model3.predict(X_train1).flatten()
train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_train1})
train_results
# Out:
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#       Train Predictions  Actuals
# 0            199.640106    195.0
# 1            193.331284    185.0
# 2            185.615234    208.0
# 3            211.490128    290.0
# 4            284.531952    267.0
# ...                 ...      ...
# 2228         225.333755    197.0
# 2229         189.895889    216.0
# 2230         231.652084    223.0
# 2231         217.553619    269.0
# 2232         277.974915    233.0
#
# [2233 rows x 2 columns]

# %%
plt.plot(train_results['Actuals'][1:50], label='Actual')
plt.plot(train_results['Train Predictions'][1:50], label='Predicted')
plt.legend()
plt.show()

# %%
val_predictions = model3.predict(X_val1).flatten()
val_results = pd.DataFrame(data={'Train Predictions':val_predictions, 'Actuals':y_val1})
val_results
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#      Train Predictions  Actuals
# 0           206.638657    183.0
# 1           182.646118    206.0
# 2           214.321732    189.0
# 3           183.456039    181.0
# 4           186.919998    189.0
# ..                 ...      ...
# 628         184.633560    193.0
# 629         214.485855    199.0
# 630         193.392654    197.0
# 631         203.581039    197.0
# 632         194.461472    190.0
#
# [633 rows x 2 columns]

# %%
plt.plot(val_results['Actuals'][1:50], label='Actual')
plt.plot(val_results['Train Predictions'][1:50], label='Predicted')
plt.legend()
plt.show()

# %%
test_predictions = model3.predict(X_test1).flatten()
test_results = pd.DataFrame(data={'Train Predictions':test_predictions, 'Actuals':y_test1})
test_results
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#      Train Predictions  Actuals
# 0           200.805664    190.0
# 1           184.942429    177.0
# 2           179.642319    172.0
# 3           172.839828    170.0
# 4           169.344650    197.0
# ..                 ...      ...
# 310         153.138260    134.0
# 311         138.140915    144.0
# 312         149.012741    155.0
# 313         151.283325    155.0
# 314         149.212326    152.0
#
# [315 rows x 2 columns]

# %%
plt.plot(test_results['Train Predictions'][1:50], label='Predicted')
plt.plot(test_results['Actuals'][1:50], label='Actual')
plt.legend()
plt.show()

# %% [markdown]
# # CNN+GRU

# %%
model4 = Sequential()

# Convolutional layer
model4.add(Conv1D(filters=128, kernel_size=3, activation='relu', input_shape=(X_train1.shape[1], 1)))

# GRU layer
model4.add(GRU(units=16, return_sequences=False))  # Return_sequences=False for final GRU layer

# Dense layers
model4.add(Dense(8, activation='relu'))
model4.add(Dropout(0.2)) 
model4.add(Dense(1, activation='linear'))

model4.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                      │ (None, 4, 128)              │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_1 (GRU)                          │ (None, 16)                  │           7,008 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 8)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,665 (29.94 KB)
#  Trainable params: 7,665 (29.94 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp4 = ModelCheckpoint('/kaggle/working/model4.keras', save_best_only=True)
model4.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0005), 
               metrics=[RootMeanSquaredError()])

# %%
model4.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), 
           epochs=100, callbacks=[cp4])
# Out:
# Epoch 1/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 32508.2090 - root_mean_squared_error: 180.2845 - val_loss: 34276.1641 - val_root_mean_squared_error: 185.1382
# Epoch 2/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31210.6523 - root_mean_squared_error: 176.6338 - val_loss: 33533.5625 - val_root_mean_squared_error: 183.1217
# Epoch 3/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29753.8457 - root_mean_squared_error: 172.4351 - val_loss: 33003.8750 - val_root_mean_squared_error: 181.6697
# Epoch 4/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30937.4668 - root_mean_squared_error: 175.8485 - val_loss: 32398.7070 - val_root_mean_squared_error: 179.9964
# Epoch 5/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29112.7383 - root_mean_squared_error: 170.6112 - val_loss: 31256.4102 - val_root_mean_squared_error: 176.7948
# Epoch 6/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27968.3262 - root_mean_squared_error: 167.2267 - val_loss: 30039.0176 - val_root_mean_squared_error: 173.3177
# Epoch 7/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 26792.5117 - root_mean_squared_error: 163.6738 - val_loss: 28805.6328 - val_root_mean_squared_error: 169.7222
# Epoch 8/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 25380.5820 - root_mean_squared_error: 159.2932 - val_loss: 27294.6152 - val_root_mean_squared_error: 165.2108
# Epoch 9/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23976.5234 - root_mean_squared_error: 154.7686 - val_loss: 25860.1523 - val_root_mean_squared_error: 160.8109
# Epoch 10/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22044.1660 - root_mean_squared_error: 148.4516 - val_loss: 24423.6895 - val_root_mean_squared_error: 156.2808
# Epoch 11/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22730.4492 - root_mean_squared_error: 150.6299 - val_loss: 22983.3438 - val_root_mean_squared_error: 151.6026
# Epoch 12/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19429.2207 - root_mean_squared_error: 139.3620 - val_loss: 21548.8242 - val_root_mean_squared_error: 146.7952
# Epoch 13/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17567.6094 - root_mean_squared_error: 132.4918 - val_loss: 20135.3594 - val_root_mean_squared_error: 141.8991
# Epoch 14/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16760.0449 - root_mean_squared_error: 129.3427 - val_loss: 18772.8477 - val_root_mean_squared_error: 137.0140
# Epoch 15/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15845.5176 - root_mean_squared_error: 125.8604 - val_loss: 17482.1719 - val_root_mean_squared_error: 132.2202
# Epoch 16/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14601.9121 - root_mean_squared_error: 120.7687 - val_loss: 16222.0791 - val_root_mean_squared_error: 127.3659
# Epoch 17/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13490.4385 - root_mean_squared_error: 116.0140 - val_loss: 15053.9941 - val_root_mean_squared_error: 122.6947
# Epoch 18/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12012.2275 - root_mean_squared_error: 109.5778 - val_loss: 13959.4072 - val_root_mean_squared_error: 118.1499
# Epoch 19/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13156.5039 - root_mean_squared_error: 114.5919 - val_loss: 12947.9756 - val_root_mean_squared_error: 113.7892
# Epoch 20/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11445.1064 - root_mean_squared_error: 106.9012 - val_loss: 12034.3799 - val_root_mean_squared_error: 109.7013
# Epoch 21/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9780.6211 - root_mean_squared_error: 98.8585 - val_loss: 11208.7959 - val_root_mean_squared_error: 105.8716
# Epoch 22/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9801.9121 - root_mean_squared_error: 98.6182 - val_loss: 10481.4629 - val_root_mean_squared_error: 102.3790
# Epoch 23/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10090.4785 - root_mean_squared_error: 100.0023 - val_loss: 9831.8076 - val_root_mean_squared_error: 99.1555
# Epoch 24/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8464.0635 - root_mean_squared_error: 91.9178 - val_loss: 9254.7686 - val_root_mean_squared_error: 96.2017
# Epoch 25/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7611.6909 - root_mean_squared_error: 87.2208 - val_loss: 8785.2939 - val_root_mean_squared_error: 93.7299
# Epoch 26/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7175.4028 - root_mean_squared_error: 84.5874 - val_loss: 8375.4629 - val_root_mean_squared_error: 91.5176
# Epoch 27/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7575.9658 - root_mean_squared_error: 86.9577 - val_loss: 8041.6455 - val_root_mean_squared_error: 89.6752
# Epoch 28/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8410.3076 - root_mean_squared_error: 91.4566 - val_loss: 7760.4849 - val_root_mean_squared_error: 88.0936
# Epoch 29/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6729.0854 - root_mean_squared_error: 81.9171 - val_loss: 7532.2300 - val_root_mean_squared_error: 86.7884
# Epoch 30/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7408.2720 - root_mean_squared_error: 85.8933 - val_loss: 8493.2598 - val_root_mean_squared_error: 92.1589
# Epoch 31/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8056.8418 - root_mean_squared_error: 89.4065 - val_loss: 8106.6953 - val_root_mean_squared_error: 90.0372
# Epoch 32/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7336.9741 - root_mean_squared_error: 85.5972 - val_loss: 7775.4028 - val_root_mean_squared_error: 88.1782
# Epoch 33/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7175.6968 - root_mean_squared_error: 84.6305 - val_loss: 7513.1738 - val_root_mean_squared_error: 86.6786
# Epoch 34/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7623.3403 - root_mean_squared_error: 86.9997 - val_loss: 8479.4727 - val_root_mean_squared_error: 92.0841
# Epoch 35/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7504.5605 - root_mean_squared_error: 86.5981 - val_loss: 8030.6621 - val_root_mean_squared_error: 89.6140
# Epoch 36/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6834.6519 - root_mean_squared_error: 82.5936 - val_loss: 7696.7773 - val_root_mean_squared_error: 87.7313
# Epoch 37/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6826.3779 - root_mean_squared_error: 82.5684 - val_loss: 7418.7993 - val_root_mean_squared_error: 86.1325
# Epoch 38/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7118.4243 - root_mean_squared_error: 84.2485 - val_loss: 7220.8105 - val_root_mean_squared_error: 84.9753
# Epoch 39/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6956.9692 - root_mean_squared_error: 83.1813 - val_loss: 7068.9082 - val_root_mean_squared_error: 84.0768
# Epoch 40/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6365.7407 - root_mean_squared_error: 79.6681 - val_loss: 6959.4106 - val_root_mean_squared_error: 83.4231
# Epoch 41/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6874.3330 - root_mean_squared_error: 82.6841 - val_loss: 6872.6187 - val_root_mean_squared_error: 82.9013
# Epoch 42/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5661.6689 - root_mean_squared_error: 75.0804 - val_loss: 6820.7905 - val_root_mean_squared_error: 82.5881
# Epoch 43/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6257.2388 - root_mean_squared_error: 79.0684 - val_loss: 6783.7202 - val_root_mean_squared_error: 82.3633
# Epoch 44/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6388.4165 - root_mean_squared_error: 79.9032 - val_loss: 6754.8359 - val_root_mean_squared_error: 82.1878
# Epoch 45/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6417.4341 - root_mean_squared_error: 80.0787 - val_loss: 6720.8481 - val_root_mean_squared_error: 81.9808
# Epoch 46/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6968.5137 - root_mean_squared_error: 83.4160 - val_loss: 6709.0918 - val_root_mean_squared_error: 81.9090
# Epoch 47/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7300.2793 - root_mean_squared_error: 85.1570 - val_loss: 6699.0981 - val_root_mean_squared_error: 81.8480
# Epoch 48/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6589.1450 - root_mean_squared_error: 81.0526 - val_loss: 6689.6372 - val_root_mean_squared_error: 81.7902
# Epoch 49/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7050.0391 - root_mean_squared_error: 83.6340 - val_loss: 6670.8071 - val_root_mean_squared_error: 81.6750
# Epoch 50/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5614.8550 - root_mean_squared_error: 74.8744 - val_loss: 6664.3564 - val_root_mean_squared_error: 81.6355
# Epoch 51/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6143.2329 - root_mean_squared_error: 78.3232 - val_loss: 6660.2070 - val_root_mean_squared_error: 81.6101
# Epoch 52/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6860.1255 - root_mean_squared_error: 82.7165 - val_loss: 6660.7764 - val_root_mean_squared_error: 81.6136
# Epoch 53/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5973.4292 - root_mean_squared_error: 77.1423 - val_loss: 6655.1494 - val_root_mean_squared_error: 81.5791
# Epoch 54/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6527.9712 - root_mean_squared_error: 80.6621 - val_loss: 6652.6919 - val_root_mean_squared_error: 81.5640
# Epoch 55/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5695.5889 - root_mean_squared_error: 75.4210 - val_loss: 6648.2344 - val_root_mean_squared_error: 81.5367
# Epoch 56/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6271.9155 - root_mean_squared_error: 79.1609 - val_loss: 6644.3579 - val_root_mean_squared_error: 81.5129
# Epoch 57/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5733.8867 - root_mean_squared_error: 75.5766 - val_loss: 6645.5796 - val_root_mean_squared_error: 81.5204
# Epoch 58/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6183.0615 - root_mean_squared_error: 78.5884 - val_loss: 6649.2612 - val_root_mean_squared_error: 81.5430
# Epoch 59/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6971.2422 - root_mean_squared_error: 82.3564 - val_loss: 6644.9785 - val_root_mean_squared_error: 81.5167
# Epoch 60/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6708.8960 - root_mean_squared_error: 81.7039 - val_loss: 6645.0586 - val_root_mean_squared_error: 81.5172
# Epoch 61/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6689.2930 - root_mean_squared_error: 81.7288 - val_loss: 5842.6602 - val_root_mean_squared_error: 76.4373
# Epoch 62/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5765.2129 - root_mean_squared_error: 75.8306 - val_loss: 5628.3896 - val_root_mean_squared_error: 75.0226
# Epoch 63/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5734.9741 - root_mean_squared_error: 75.6453 - val_loss: 5547.9570 - val_root_mean_squared_error: 74.4846
# Epoch 64/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5536.0698 - root_mean_squared_error: 74.2769 - val_loss: 5422.7393 - val_root_mean_squared_error: 73.6393
# Epoch 65/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5199.5049 - root_mean_squared_error: 71.9953 - val_loss: 5392.2690 - val_root_mean_squared_error: 73.4321
# Epoch 66/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5115.4331 - root_mean_squared_error: 71.4557 - val_loss: 5291.2783 - val_root_mean_squared_error: 72.7412
# Epoch 67/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5510.7603 - root_mean_squared_error: 74.2073 - val_loss: 5306.1636 - val_root_mean_squared_error: 72.8434
# Epoch 68/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5619.5010 - root_mean_squared_error: 74.8959 - val_loss: 5374.7749 - val_root_mean_squared_error: 73.3129
# Epoch 69/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5405.9033 - root_mean_squared_error: 73.4348 - val_loss: 5144.4009 - val_root_mean_squared_error: 71.7245
# Epoch 70/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5515.4995 - root_mean_squared_error: 74.0596 - val_loss: 5113.4321 - val_root_mean_squared_error: 71.5083
# Epoch 71/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5350.3687 - root_mean_squared_error: 73.0879 - val_loss: 5039.6182 - val_root_mean_squared_error: 70.9903
# Epoch 72/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4947.7100 - root_mean_squared_error: 70.1969 - val_loss: 5004.9233 - val_root_mean_squared_error: 70.7455
# Epoch 73/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4624.6313 - root_mean_squared_error: 67.8522 - val_loss: 4953.0674 - val_root_mean_squared_error: 70.3780
# Epoch 74/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4920.1484 - root_mean_squared_error: 70.0469 - val_loss: 5060.3325 - val_root_mean_squared_error: 71.1360
# Epoch 75/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5246.9590 - root_mean_squared_error: 72.4165 - val_loss: 4917.6123 - val_root_mean_squared_error: 70.1257
# Epoch 76/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4630.7524 - root_mean_squared_error: 67.9897 - val_loss: 4898.0728 - val_root_mean_squared_error: 69.9862
# Epoch 77/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4680.8691 - root_mean_squared_error: 68.3550 - val_loss: 5251.5073 - val_root_mean_squared_error: 72.4673
# Epoch 78/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5678.8628 - root_mean_squared_error: 75.1661 - val_loss: 4807.4976 - val_root_mean_squared_error: 69.3361
# Epoch 79/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6283.0171 - root_mean_squared_error: 78.8160 - val_loss: 4847.3306 - val_root_mean_squared_error: 69.6228
# Epoch 80/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4554.3247 - root_mean_squared_error: 67.3773 - val_loss: 5200.0039 - val_root_mean_squared_error: 72.1111
# Epoch 81/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5280.5288 - root_mean_squared_error: 72.6103 - val_loss: 4758.0024 - val_root_mean_squared_error: 68.9783
# Epoch 82/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5129.5044 - root_mean_squared_error: 71.5705 - val_loss: 4742.4307 - val_root_mean_squared_error: 68.8653
# Epoch 83/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5067.8843 - root_mean_squared_error: 71.0972 - val_loss: 4669.2471 - val_root_mean_squared_error: 68.3319
# Epoch 84/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4735.4917 - root_mean_squared_error: 68.7202 - val_loss: 4737.6904 - val_root_mean_squared_error: 68.8309
# Epoch 85/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4865.2246 - root_mean_squared_error: 69.6795 - val_loss: 4623.1782 - val_root_mean_squared_error: 67.9940
# Epoch 86/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5002.3052 - root_mean_squared_error: 70.6800 - val_loss: 4583.9009 - val_root_mean_squared_error: 67.7045
# Epoch 87/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4974.5015 - root_mean_squared_error: 70.2266 - val_loss: 4625.3320 - val_root_mean_squared_error: 68.0098
# Epoch 88/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5879.7378 - root_mean_squared_error: 76.2882 - val_loss: 4543.7954 - val_root_mean_squared_error: 67.4077
# Epoch 89/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4580.5454 - root_mean_squared_error: 67.5963 - val_loss: 4347.1816 - val_root_mean_squared_error: 65.9332
# Epoch 90/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5025.7495 - root_mean_squared_error: 70.8355 - val_loss: 4458.2852 - val_root_mean_squared_error: 66.7704
# Epoch 91/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4799.0254 - root_mean_squared_error: 69.0940 - val_loss: 4366.8081 - val_root_mean_squared_error: 66.0818
# Epoch 92/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4754.5933 - root_mean_squared_error: 68.8598 - val_loss: 4359.8872 - val_root_mean_squared_error: 66.0294
# Epoch 93/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4680.1016 - root_mean_squared_error: 68.2818 - val_loss: 5299.4990 - val_root_mean_squared_error: 72.7977
# Epoch 94/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5628.3647 - root_mean_squared_error: 74.8070 - val_loss: 4899.2466 - val_root_mean_squared_error: 69.9946
# Epoch 95/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4753.9878 - root_mean_squared_error: 68.8162 - val_loss: 4634.7197 - val_root_mean_squared_error: 68.0788
# Epoch 96/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5349.2534 - root_mean_squared_error: 72.9830 - val_loss: 4547.5898 - val_root_mean_squared_error: 67.4358
# Epoch 97/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5390.7974 - root_mean_squared_error: 73.0381 - val_loss: 4329.7051 - val_root_mean_squared_error: 65.8005
# Epoch 98/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5044.5908 - root_mean_squared_error: 70.8760 - val_loss: 4466.6616 - val_root_mean_squared_error: 66.8331
# Epoch 99/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4548.0708 - root_mean_squared_error: 67.3214 - val_loss: 4179.6768 - val_root_mean_squared_error: 64.6504
# Epoch 100/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5032.2500 - root_mean_squared_error: 70.8748 - val_loss: 4127.0205 - val_root_mean_squared_error: 64.2419

# %%
from tensorflow.keras.models import load_model
model4 = load_model('/kaggle/working/model4.keras')

# %%
# Evaluate the model on the train data
train_result = model4.predict(X_train1)

# Calculate metrics
mse = mean_squared_error(y_train1, train_result)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_train1, train_result)
r2 = r2_score(y_train1, train_result)

# Print the results
print("Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (Accuracy): {r2:.4f}")
# Out:
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Evaluation Metrics:
# Mean Absolute Error (MAE): 32.7843
# Mean Squared Error (MSE): 3466.8776
# Root Mean Squared Error (RMSE): 58.8802
# R-squared (Accuracy): 0.3290

# %%
# Evaluate the model on the validation data
val_result = model4.predict(X_val1)

# Calculate metrics
mse = mean_squared_error(y_val1, val_result)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_val1, val_result)
r2 = r2_score(y_val1, val_result)

# Print the results
print("Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (Accuracy): {r2:.4f}")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Evaluation Metrics:
# Mean Absolute Error (MAE): 45.7067
# Mean Squared Error (MSE): 4127.0202
# Root Mean Squared Error (RMSE): 64.2419
# R-squared (Accuracy): 0.3650

# %%
# Evaluate the model on the test data
test_result = model4.predict(X_test1)

# Calculate metrics
mse = mean_squared_error(y_test1, test_result)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test1, test_result)
r2 = r2_score(y_test1, test_result)

# Print the results
print("Evaluation Metrics:")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Squared Error (MSE): {mse:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"R-squared (Accuracy): {r2:.4f}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Evaluation Metrics:
# Mean Absolute Error (MAE): 30.3486
# Mean Squared Error (MSE): 1803.0033
# Root Mean Squared Error (RMSE): 42.4618
# R-squared (Accuracy): 0.4544
